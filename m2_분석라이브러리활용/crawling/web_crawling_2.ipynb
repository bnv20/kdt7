# %% [markdown]
# BeautifulSoup 모듈
# - 홈페이지 내 데이터를 쉽게 추출할 수 있게 해주는 파이썬 외부 라이브러리
# - 웹 문서 내 수많은 HTML 태그들을 parser를 활용해 사용하기 편한 파이썬 객체로 만들어 제공
# - 웹 문서 구조를 알고 있다면 편하게 데이터를 뽑아 활용할 수 있음
#
# 기존방식과의 차이점
# - 정규 표현식, 문자열 함수 등을 활용하여 홈페이지 텍스트 내 패턴을 분석하여 하나씩 원하는 데이터를 찾아가는 형식
# - BS는 HTML 문서를 태그를 기반으로 구조화하여 태그로 원하는 데이터를 찾아가는 형식

# %%
html_doc = """
<html lang="en">
<head><title>crawl</title></head>
<body>
<p class="a" align="center"> text1</p>
<p class="b" align="center"> text2</p>
<p class="c" align="center"> text3</p>
<div><img src="/source" width="300" height="200"></div>
</body>
</html>
"""
from bs4 import BeautifulSoup
soup = BeautifulSoup(html_doc, 'html.parser')
print(soup.prettify())
# Out:
# <html lang="en">
#  <head>
#   <title>
#    crawl
#   </title>
#  </head>
#  <body>
#   <p align="center" class="a">
#    text1
#   </p>
#   <p align="center" class="b">
#    text2
#   </p>
#   <p align="center" class="c">
#    text3
#   </p>
#   <div>
#    <img height="200" src="/source" width="300"/>
#   </div>
#  </body>
# </html>

# %%
html = """
<html><body>
  <h1>스크레이핑이란?</h1>
  <p>웹 페이지를 분석하는 것</p>
  <p>원하는 부분을 추출하는 것</p>
</body></html>
"""
soup = BeautifulSoup(html, 'html.parser')
h1 = soup.html.body.h1
p1 = soup.html.body.p
# p2 = p1.next_sibling
p2 = p1.next_sibling.next_sibling

print(h1.string)
print(p1.string)
print(p2.string)
# Out:
# 스크레이핑이란?
# 웹 페이지를 분석하는 것
# 원하는 부분을 추출하는 것

# %% [markdown]
# find() : HTML의 해당 태그에 대한 첫 번째 정보를 가져옴
# - find(속성='값') : HTML 해당 속성과 일치하는 값에 대한 첫 번째 정보를 가져옴
#
# find_all() :
# - HTML의 해당 태그에 대한 모든 정보를 리스트 형식으로 가져옴. limit 옵션으로 개수 지정 가능
# - CSS 속성으로 필터링(class_로 클래스를 직접 사용 혹은 attrs에서 속성 = 값으로 필터링)

# %%
html = """
<html><body>
  <h1 id='title'>스크레이핑이란?</h1>
  <p id='body'>웹 페이지를 분석하는 것</p>
  <p>원하는 부분을 추출하는 것</p>
</body></html>
"""

soup = BeautifulSoup(html, 'html.parser')
title = soup.find(id='title')
body = soup.find(id='body')

print(title.string)
print(body.string)
print(title.text)
print(body.text)
print(body.get_text())
# Out:
# 스크레이핑이란?
# 웹 페이지를 분석하는 것
# 스크레이핑이란?
# 웹 페이지를 분석하는 것
# 웹 페이지를 분석하는 것

# %%
# texts = soup.findAll('p')
texts = soup.find_all('p')
for t in texts:
    print(t.text)
# Out:
# 웹 페이지를 분석하는 것
# 원하는 부분을 추출하는 것

# %%
# urlopen()과 BeautifulSoup의 조합
import warnings
warnings.filterwarnings('ignore')
from bs4 import BeautifulSoup
import urllib.request as req
url = "http://www.kma.go.kr/weather/forecast/mid-term-rss3.jsp"
res = req.urlopen(url)
soup = BeautifulSoup(res, 'html.parser')
title = soup.find('title').string
wf = soup.find('wf').string
print(title,'\n')
print(wf)
# Out:
# 기상청 육상 중기예보
#
# ○ (강수) 27일(수)은 수도권과 강원영서에 비가 오겠습니다. <br />○ (기온) 이번 예보기간 아침 기온은 22~25도, 낮 기온은 29~34도로 어제(21일, 아침최저기온 20~24도, 낮최고기온 23~32도)보다 높겠습니다.<br /><br />* 이번 예보기간 북태평양고기압의 발달 여부와 정체전선의 위치에 따라 강수 구역이 변동될 수 있으며, 정체전선의 영향권에서 벗어난 지역에도 대기 불안정으로 소나기가 내릴 가능성이 있겠으니, 앞으로 발표되는 기상정보를 참고하기 바랍니다.

# %%
import requests
import re

url = "http://www.kma.go.kr/weather/forecast/mid-term-rss3.jsp"
data = requests.get(url).text
soup = BeautifulSoup(data,'html.parser')
wf = soup.find('wf').string
wf = re.sub('[^0-9가-힣]', ' ', wf)
wf
# Out:
# '   강수  27일 수 은 수도권과 강원영서에 비가 오겠습니다           기온  이번 예보기간 아침 기온은 22 25도  낮 기온은 29 34도로 어제 21일  아침최저기온 20 24도  낮최고기온 23 32도 보다 높겠습니다               이번 예보기간 북태평양고기압의 발달 여부와 정체전선의 위치에 따라 강수 구역이 변동될 수 있으며  정체전선의 영향권에서 벗어난 지역에도 대기 불안정으로 소나기가 내릴 가능성이 있겠으니  앞으로 발표되는 기상정보를 참고하기 바랍니다 '

# %% [markdown]
# #### 과제0722_2
# wf를 다시 정렬하여 불필요한 부분을 제거해서 아래와 같은 형식으로 출력하세요.

# %% [markdown]
# '(강수) 23일(토) 오후부터 24일(일) 오전 사이 전국에 비가 오겠고, 강원영동은 24일(일) 오후까지 이어지는 곳이 있겠습니다. 27일(수)은 수도권과 강원영서에 비가 오겠습니다.(기온) 이번 예보기간 아침 기온은 22~26도로 어제(19일, 아침최저기온 20~24도)보다 조금 높겠고, 낮 기온은 28~34도로 어제(낮최고기온 27~34도)와 비슷하겠습니다.(주말전망) 23일(토) 오후부터 24일(일) 오전 사이 전국에 비가 오겠고, 강원영동은 24일(일) 오후까지 이어지는 곳이 있겠습니다.

# %%
texts = soup.find_all('wf')
for t in texts:
    t = t.text
    t = re.sub('[^0-9가-힣]',' ', t)
    print(t,'\n')
# Out:
#    강수  27일 수 은 수도권과 강원영서에 비가 오겠습니다           기온  이번 예보기간 아침 기온은 22 25도  낮 기온은 29 34도로 어제 21일  아침최저기온 20 24도  낮최고기온 23 32도 보다 높겠습니다               이번 예보기간 북태평양고기압의 발달 여부와 정체전선의 위치에 따라 강수 구역이 변동될 수 있으며  정체전선의 영향권에서 벗어난 지역에도 대기 불안정으로 소나기가 내릴 가능성이 있겠으니  앞으로 발표되는 기상정보를 참고하기 바랍니다
#
# 구름많음
#
# 맑음
#
# 구름많음
#
# 맑음
#
# 구름많음
#
# 구름많고 비
#
# 구름많음
#
# 구름많음
#
# 맑음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 맑음
#
# 구름많음
#
# 맑음
#
# 구름많음
#
# 구름많고 비
#
# 구름많음
#
# 구름많음
#
# 맑음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 맑음
#
# 구름많음
#
# 맑음
#
# 구름많음
#
# 구름많고 비
#
# 구름많음
#
# 구름많음
#
# 맑음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 맑음
#
# 구름많음
#
# 맑음
#
# 구름많음
#
# 구름많고 비
#
# 구름많음
#
# 구름많음
#
# 맑음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 맑음
#
# 구름많음
#
# 맑음
#
# 구름많음
#
# 구름많고 비
#
# 구름많음
#
# 구름많음
#
# 맑음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 맑음
#
# 구름많음
#
# 맑음
#
# 구름많음
#
# 구름많고 비
#
# 구름많음
#
# 구름많음
#
# 맑음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 맑음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많고 비
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 흐림
#
# 흐림
#
# 구름많음
#
# 맑음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많고 비
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 흐림
#
# 흐림
#
# 구름많음
#
# 구름많음
#
# 흐림
#
# 흐림
#
# 구름많음
#
# 흐림
#
# 흐림
#
# 흐림
#
# 구름많음
#
# 맑음
#
# 맑음
#
# 맑음
#
# 흐림
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 맑음
#
# 구름많음
#
# 구름많음
#
# 맑음
#
# 구름많음
#
# 구름많음
#
# 맑음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 맑음
#
# 구름많음
#
# 구름많음
#
# 맑음
#
# 구름많음
#
# 구름많음
#
# 맑음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 맑음
#
# 구름많음
#
# 구름많음
#
# 맑음
#
# 구름많음
#
# 구름많음
#
# 맑음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 맑음
#
# 구름많음
#
# 맑음
#
# 맑음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 맑음
#
# 구름많음
#
# 맑음
#
# 맑음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 맑음
#
# 구름많음
#
# 맑음
#
# 맑음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 흐림
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 맑음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 흐림
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 맑음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 흐림
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 맑음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 흐림
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 맑음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 흐림
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 맑음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 흐림
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 맑음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 흐림
#
# 구름많음
#
# 흐림
#
# 흐림
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 흐림
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 흐림
#
# 구름많음
#
# 흐림
#
# 흐림
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 흐림
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 흐림
#
# 구름많음
#
# 흐림
#
# 흐림
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 흐림
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 흐림
#
# 구름많음
#
# 흐림
#
# 흐림
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 흐림
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 흐림
#
# 구름많음
#
# 흐림
#
# 흐림
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 흐림
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 흐림
#
# 구름많음
#
# 흐림
#
# 흐림
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 흐림
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음

# %%
req = requests.get('https://naver.com')
html = req.text
# print(html)

soup = BeautifulSoup(html,'html.parser')
# result = soup.find_all('span',class_='blind')[0]
# result = soup.find_all('span',class_="fix")
result = soup.find_all('span',attrs={'class':"fix"})
# result = soup.find_all('span')

result
# Out:
# [<span class="fix"><span class="common_ico_kwd"><i class="imsc ico_search"></i></span><span>@txt@</span></span>,
#  <span class="fix"><span class="common_ico_kwd"><i class="imsc ico_search"></i></span>@txt@</span>,
#  <span class="fix"><span class="common_ico_kwd"><i class="imsc ico_search"></i></span>@txt@</span>,
#  <span class="fix"><span class="common_ico_kwd"><i class="imsc ico_search"></i></span>@query@ <span class="context">@intend@</span></span>]

# %%
import re

req = requests.get('https://naver.com')
soup = BeautifulSoup(html,'html.parser')
print(soup.find_all(string='네이버'))
print(soup.find_all(string=re.compile('네이버')))
# Out:
# ['네이버']
# ['네이버', '네이버를 시작페이지로', '쥬니어네이버', '언론사가 직접 편집한 뉴스들을 네이버 홈에서 바로 보실 수 있습니다.', '네이버스포츠', '네이버스포츠', '네이버스포츠', '네이버스포츠', '네이버스포츠', '네이버스포츠', '네이버스포츠', '네이버스포츠', '네이버스포츠', '네이버스포츠', '네이버스포츠', '네이버 멤버십으로 MLB 주요 경기 프리패스!', '네이버스포츠', 'PBA TOUR (네이버스포츠)', 'PBA TOUR (네이버스포츠)', '크보연구소_네이버스포츠', '크보연구소_네이버스포츠', '크보연구소_네이버스포츠', '네이버 개발자 센터', '네이버 D2', '네이버 D2SF', '네이버 랩스', '네이버 정책 및 약관', '네이버 정책']

# %% [markdown]
# select_one(), select()
# - CSS 선택자를 활용하여 원하는 정보를 가져옴(태그를 검색하는 find, find_all과 비슷함)
# - class는 ., id는 #로 표시

# %%
import urllib.request as req

url = "https://finance.naver.com/marketindex/"

res = req.urlopen(url)
soup = BeautifulSoup(res, 'html.parser')
# price = soup.select_one('div.head_info > span.value').string
usd = soup.select_one('#exchangeList > li.on > a.head.usd > div > span.value').string

print('usd/krw =', usd)
# Out:
# usd/krw = 1,313.00

# %%
html_doc = """<html><head><title>The Dormouse's story</title></head>
<body>
<div></div>
<p class="title"><b>The Dormouse's story</b></p>

<p class="story">Once upon a time there were three little sisters; and their names were
<a href="http://example.com/elsie" class="sister" id="link1">Elsie</a>,
<a href="http://example.com/lacie" class="sister" id="link2">Lacie</a> and
<a href="http://example.com/tillie" class="sister" id="link3">Tillie</a>;
and they lived at the bottom of a well.</p>

<p class="story">...</p>"""

# %%
# !pip install lxml
# Out:
# Requirement already satisfied: lxml in c:\users\admin\anaconda3\envs\cakd7\lib\site-packages (4.9.1)

# %%
from bs4 import BeautifulSoup

bs = BeautifulSoup(html_doc, 'html.parser') # lxml
print(bs.prettify())
# Out:
# <html>
#  <head>
#   <title>
#    The Dormouse's story
#   </title>
#  </head>
#  <body>
#   <div>
#   </div>
#   <p class="title">
#    <b>
#     The Dormouse's story
#    </b>
#   </p>
#   <p class="story">
#    Once upon a time there were three little sisters; and their names were
#    <a class="sister" href="http://example.com/elsie" id="link1">
#     Elsie
#    </a>
#    ,
#    <a class="sister" href="http://example.com/lacie" id="link2">
#     Lacie
#    </a>
#    and
#    <a class="sister" href="http://example.com/tillie" id="link3">
#     Tillie
#    </a>
#    ;
# and they lived at the bottom of a well.
#   </p>
#   <p class="story">
#    ...
#   </p>
#  </body>
# </html>

# %%
bs.title
# Out:
# <title>The Dormouse's story</title>

# %%
bs.title.name
# Out:
# 'title'

# %%
bs.title.parent.name
# Out:
# 'head'

# %%
bs.p
# Out:
# <p class="title"><b>The Dormouse's story</b></p>

# %%
bs.a
# Out:
# <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>

# %%
bs.find_all('a')
# Out:
# [<a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
#  <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a>,
#  <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>]

# %%
bs.find(id='link3')
# Out:
# <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>

# %%
bs.a['class']
# Out:
# ['sister']

# %%
for link in bs.find_all('a'):
    print(link.get('href'))
# Out:
# http://example.com/elsie
# http://example.com/lacie
# http://example.com/tillie

# %%
bs.find_all()
# Out:
# [<html><head><title>The Dormouse's story</title></head>
#  <body>
#  <div></div>
#  <p class="title"><b>The Dormouse's story</b></p>
#  <p class="story">Once upon a time there were three little sisters; and their names were
#  <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
#  <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a> and
#  <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>;
#  and they lived at the bottom of a well.</p>
#  <p class="story">...</p></body></html>,
#  <head><title>The Dormouse's story</title></head>,
#  <title>The Dormouse's story</title>,
#  <body>
#  <div></div>
#  <p class="title"><b>The Dormouse's story</b></p>
#  <p class="story">Once upon a time there were three little sisters; and their names were
#  <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
#  <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a> and
#  <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>;
#  and they lived at the bottom of a well.</p>
#  <p class="story">...</p></body>,
#  <div></div>,
#  <p class="title"><b>The Dormouse's story</b></p>,
#  <b>The Dormouse's story</b>,
#  <p class="story">Once upon a time there were three little sisters; and their names were
#  <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
#  <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a> and
#  <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>;
#  and they lived at the bottom of a well.</p>,
#  <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
#  <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a>,
#  <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>,
#  <p class="story">...</p>]

# %%
bs.find_all('p')
# Out:
# [<p class="title"><b>The Dormouse's story</b></p>,
#  <p class="story">Once upon a time there were three little sisters; and their names were
#  <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
#  <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a> and
#  <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>;
#  and they lived at the bottom of a well.</p>,
#  <p class="story">...</p>]

# %% [markdown]
# #### string vs. get_text()
# - get_text()를 이용하면 한방에 현재 HTML 문서의 모든 텍스트를 추출할 수 있습니다. 조금 더 정확히 표현하면 get_text() 메서드는 현재 태그를 포함하여 모든 하위 태그를 제거하고 유니코드 텍스트만 들어있는 문자열을 반환
# - string의 경우 문자열이 없으면 None을 출력하지만, get_text()의 경우 유니코드 형식으로 텍스트까지 문자열로 반환하기 때문에  아무 정보도 출력되지 않는다.
# - string 속성은 태그(tag) 내 문자열을 반환. get_text()를 사용하더라도 정확하게 문자열을 추출하기 위해서는 항상 마지막 태그에 메서드를 사용

# %%
bs = BeautifulSoup(html_doc, 'html.parser')
bs
# Out:
# <html><head><title>The Dormouse's story</title></head>
# <body>
# <div></div>
# <p class="title"><b>The Dormouse's story</b></p>
# <p class="story">Once upon a time there were three little sisters; and their names were
# <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
# <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a> and
# <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>;
# and they lived at the bottom of a well.</p>
# <p class="story">...</p></body></html>

# %%
print(bs.string)
# Out:
# None

# %%
print(bs.get_text())
# Out:
# The Dormouse's story
#
#
# The Dormouse's story
# Once upon a time there were three little sisters; and their names were
# Elsie,
# Lacie and
# Tillie;
# and they lived at the bottom of a well.
# ...

# %%
print(bs.find('div').string)
# Out:
# None

# %%
print(bs.find('div').get_text())

# %%
print(bs.find('body').string)
# Out:
# None

# %%
bs.find('body').get_text()
# Out:
# "\n\nThe Dormouse's story\nOnce upon a time there were three little sisters; and their names were\nElsie,\nLacie and\nTillie;\nand they lived at the bottom of a well.\n..."

# %%
bs.a.string
# Out:
# 'Elsie'

# %%
li = bs.find_all('p')
for i in li:
    print(i.string)
# Out:
# The Dormouse's story
# None
# ...

# %%
for i in li:
    print(i.get_text())
# Out:
# The Dormouse's story
# Once upon a time there were three little sisters; and their names were
# Elsie,
# Lacie and
# Tillie;
# and they lived at the bottom of a well.
# ...

# %% [markdown]
# #### urllib + bs

# %%
import urllib.request as rq

url = 'https://news.naver.com/main/main.naver?mode=LSD&mid=shm&sid1=100'
html = rq.urlopen(url)
bs = BeautifulSoup(html, 'lxml')
text = bs.find('p')
text = text.get_text()
text
# Out:
# 'AiRS추천으로 구성된 뉴스를 제공합니다.'

# %%
bs.find('div').find('a').string
# Out:
# '메인 메뉴로 바로가기'

# %%
items = bs.find('div').find_all('a')
for item in items:
    print(item.get_text())
# Out:
# 메인 메뉴로 바로가기
# 본문으로 바로가기
# 검색
# NAVER
# 뉴스
# TV연예
# 스포츠
# 날씨
# 프리미엄
# 언론사별
# 정치 선택됨
# 경제
# 사회
# 생활/문화
# IT/과학
# 세계
# 랭킹
# 신문보기
# 오피니언
# TV
# 팩트체크
# 전체 언론사
# 뉴스스탠드
# 라이브러리
# 전체 언론사
# 뉴스스탠드
# 라이브러리
# 정치
# 대통령실
# 국회/정당
# 북한
# 행정
# 국방/외교
# 정치일반
#
#
# 안내헤드라인 뉴스
#
#
#
# 권성동 "경찰 집단반발은 배부른 밥투정…대우조선 경영진 물러나야"
# [속보] 권성동 "박두선 등 대우조선 경영진, 부실방만 책임지고 물러나야"
# 권성동 "대우조선 경영진, 방만 경영 책임지고 물러나야"
# 권성동 "대우조선 경영진, 방만 경영 책임지고 물러나야"
# 10개의 관련뉴스 더보기
#
#
#
# 우원식 "민주유공자법이 운동권 신분 세습법? 거짓 선동"
# '셀프 보상 논란' 野 추진 '민주유공자법'…"박탈감 준다"는 혜택 뭐길래
# 우원식 "민주화유공자법, 박종철·이한열를 유공자로 인정해달라는 것"
# 여야, '민주유공자법' 공방…권성동 "운동권 신분 세습법" vs 우상호 "떡고물 바란 듯 몰아붙여"
# 19개의 관련뉴스 더보기
#
#
#
# 강승규 “‘치안본부’ 비판은 프레임…경찰국은 권한 견제용”
# 대통령실, 尹 지지율 하락세에 “새 정부 무엇 할지 자리매김하는 과정”
# 강승규 “경찰국 신설 ‘전두환식’ 비판은 프레임 공격”
# 대통령실 강승규 "왜 검사는 되고 경찰은 안되느냐? 성격이 달라서"
# 9개의 관련뉴스 더보기
#
#
#
# 나경원 "尹지지율 하락, 우리 반성부터…野공격 지나쳐"
# 나경원 “이준석, 늘 불안불안…조금 더 자숙해야”
# 나경원 "野 '탄핵' 언급 지나쳐…지지율 하락 원인은 與에 있어"
# 나경원 "이준석, 자숙하는 모습 보여야…나라면 그랬을 것"
# 9개의 관련뉴스 더보기
#
#
#
# '전 장관' 박범계, '현 장관' 한동훈 집중타격 예고… "법치농단 하는 이유 묻겠다"
#
#
#
# 박범계 "한동훈, '법치농단'하는 이유 제대로 답변해야"
# 14개의 관련뉴스 더보기
#
#
#
# 이준석, 울릉도 입도…보수텃밭 TK 지지층 다지기
#
#
#
# 이준석은 장외정치 중...이번엔 울릉도서 당원들과 저녁 식사
# 7개의 관련뉴스 더보기
#
#
#
# 이상민 "경찰국 신설, 尹·장관 위법행위…탄핵 사유에 해당"
#
#
#
# 이상민이 이상민에게…"행안장관 덕목 못 갖춰, 교체해야"
# 5개의 관련뉴스 더보기
#
#
#
# 북한, 신규 발열 나흘째 백 명대 주장…누적 477만여 명
#
#
# 동영상기사
#
# 북한 "신규 발열자 처음으로 50명대 집계"
# 16개의 관련뉴스 더보기
#
#
#
# 29일 워싱턴서 한미 국방장관회담… "확장억제 등 동맹 현안 논의"
#
#
#
# 北 전승절 직후 한미 국방장관 또 만난다
# 13개의 관련뉴스 더보기
#
#
#
# 남래진 선관위원 후보자 “‘사적 채용’ 논란 우모 씨 부친, 선관위원 사퇴해야”
#
#
#
# 남래진 후보자 "선관위, 위상·권위 크게 추락…새롭게 태어나야"
# 6개의 관련뉴스 더보기
#
#
#
# 尹 대통령 "그 작가네?" 출근길, 미술계 '우영우' 장애인 작품 걸었다
#
#
#
# 尹대통령, 로비 걸린 장애예술가 작품에 “몇 년전 본 그림”…金여사 예술감독 ‘인연’
# 23개의 관련뉴스 더보기
#
#
#
# 윤 대통령 국정 지지율 하락세 주춤, 그 이유는?
#
#
#
# "尹 국정지지 하락세 주춤…긍정 33.3% 부정 63.4%"
# 39개의 관련뉴스 더보기
# 우상호 "경찰 장악에 비서실장 등판...尹 지시로 해석"
#
#
#
# '경찰국 논란'에 행안부 장관 탄핵론·교체론 압박...민주당 "경찰 충견 만드는 것" 여당은 '신중 모드'"
# 30개의 관련뉴스 더보기
#
#
#
# 윤 대통령, 경찰 집단행동에 "행안부·경찰청에서 필요한 조치 할 것"
#
#
#
# [속보] 尹, 경찰 집단행동 예고에 “행안부·경찰청 필요한 조치 잘 할 것”
# 46개의 관련뉴스 더보기
#
#
# 동영상기사
#
# 민주당 예비경선 D-3…'반명 연대' 단일화 시도 계속
#
#
#
# 컷오프 앞두고 '非이재명' 후보 단일화 속도…박용진·강병원·설훈 "동참"
# 48개의 관련뉴스 더보기
#
#
#
# 차기 당대표, 이재명 42.7%…민주당 정당지지율 1위[KSOI]
#
#
#
# 민주당 차기 당대표, 이재명 42.7% 독보적 1위, 박용진 14%[KSOI]
# 8개의 관련뉴스 더보기
# 헤드라인 더보기
#
# 연재보기
# 박수찬의 軍
#
# 文정부는 경항모, 尹정부는 스텔스기…전력증강 방향이 바뀐다 [박수찬의 軍]
# ‘베이비 랩터’ KF-21, 세계 시장 흔들 ‘게임 체인저’ 될까 [박수찬의 軍]
# “지금은 맞고 그때는 틀리다?”…‘월북 논란’ SI 정보 믿을 수 있을까 [박수찬의 軍]
# “F-35 게 서라”…국산 KF-21, 세계로 날갯짓 가능할까 [박수찬의 軍]
#
#
#
#
# 김연아 10월 결혼한다…신랑은 5살 연하 성악가 고우림
# 중앙일보
#
#
#
# ‘피겨여왕’ 김연아, 5세 연하 성악가 고우림과 10월 결 …
# 매일경제
#
#
#
# ‘피겨퀸’ 김연아, 성악가 고우림과 10월 전격 결혼
# 경향신문
#
#
# 동영상기사
#
# 피겨퀸 김연아, 10월 결혼…성악가 고우림과 3년 교제 끝 …
# SBS
#
#
#
# ‘피겨 여왕’ 김연아, 10월의 신부 된다…예비신랑은 누구 …
# 조선일보
#
#
#
# 김연아, '팬텀싱어' 5세 연하 서울대 출신 고우림과 10 …
# 뉴스1
#
#
#
# 피겨여왕 김연아, 성악가 고우림과 ‘10월 결혼’
# 아시아경제
#
#
#
# [판결남] ‘기말고사 답안지’ 들고 사라진 선생님…중3 학 …
# KBS
#
#
#
# '피겨여왕' 김연아, 포레스텔라 고우림과 10월 결혼
# JTBC
#
#
#
# 윤 대통령 지지율 20%대로 경고한 20대…9.2%p 급락 …
# 한겨레
#
#
#
# "300만원 넘게 줬는데…" 부모님 집 '2in1 에어컨' …
# 한국경제
#
#
# 동영상기사
#
# 공시가 3억 시골집, 양도세·종부세 주택 수서 제외
# 연합뉴스TV
#
#
#
# 우영우 실제 모델은 자폐 진단 받은 세계적 동물학자
# 한국일보
#
#
#
# [속보]이상민 "무장 가능한 조직이 상부지시 위반 대단히  …
# 이데일리
#
#
#
# 김연아, 10월 결혼…성악가 고우림과 3년 교제 끝에 웨딩 …
# 연합뉴스
#
#
#
# "머스크, 절친 아내와 불륜…구글 창업자 이혼 사유였다"
# 머니투데이
#
#
#
# "무증상이면 5만원 내세요"…코로나 검사 회피 늘어난다
# 서울경제
#
#
#
# 김연아, 5살 연하 고우림과 결혼...3년 열애
# 파이낸셜뉴스
#
#
#
# 고우림 측 "김연아와 3년 열애...10월 결혼" (공식입 …
# YTN
#
#
#
# ‘피겨여왕’ 김연아, 5살 연하 고우림과 10월 결혼
# 국민일보
#
#
#
# 김연아, ‘포레스텔라’ 고우림과 10월 결혼
# 문화일보
#
#
#
# 15세 男학생과 지속적 성관계…28세 공부방 女선생 들통난 …
# 데일리안
#
#
# 동영상기사
#
# 철장에선 나왔지만‥"8천억 배상하라니‥"
# MBC
#
#
#
# “수지→아기 얼굴” 귀엽다 난리더니, 순식간에 망가진 이곳
# 헤럴드경제
#
#
#
# 4분기 출시 '7세대 그랜저' 대기만 벌써 3만명
# 한국경제TV
#
#
#
# 민주당 지지율, 한 주 새 9% 상승…국민의힘에 역전[KS …
# 조선비즈
#
#
#
# 이상민 “경찰서장회의, 12·12 쿠데타 준하는 상황”
# 동아일보
#
#
#
# “깨끗하고 안전해”…강물 원샷한 인도 총리, 결국 병원行
# 서울신문
#
#
#
# '피겨여왕' 김연아, 5세 연하 고우림과 10월 결혼(종합 …
# 뉴시스
#
#
#
# 피겨퀸 김연아, 10월 결혼…성악가 고우림과 웨딩마치
# TV조선
#
#
#
# 박범계 “한동훈에 ‘법치농단’ 따져 묻겠다”
# 채널A
#
#
#
# "아기 손가락 잘린 유모차, 우리와는 무관"…母 폭로에 업 …
# MBN
#
#
#
# 김의겸 "윤석열 정부를 ‘MB 2기 라고 해...전두환의  …
# 강원일보
#
#
#
# 국민의힘 수신료 폐지주장에 "비전문가적 주장" 비판한 KB …
# 미디어오늘
#
#
#
# 코로나19 인간 활동이 잠시 멈춘 사이 야생동물 세계도 웃 …
# 동아사이언스
#
#
#
# 드라마가 현실로?… 우영우 팽나무 천연기념물 조사나선 문화 …
# 세계일보
#
#
#
# "밝게 웃는 모습 화나서" 이재명·윤석열 대선 후보 벽보  …
# 부산일보
#
#
#
# 전여옥 “‘위험인물’ 류삼영 총경은 ‘정치경찰’…대기발령  …
# 디지털타임스
#
#
#
# 윤 대통령, 또 틀렸다... '반도체 15만 양병설'은 헛 …
# 오마이뉴스
#
#
#
# [인터뷰] 박지현 "이재명, 팬덤 예쁨 받으려 '애교'…문 …
# 더팩트
#
#
#
# 이상민 장관 격노 "12.12 쿠데타에 준하는 상황…경찰이 …
# 프레시안
#
#
#
# 현대차 '7세대 그랜저', 출시도 안 했는데 3만명 대기
# 전자신문
#
#
#
# 일론 머스크, 구글 창업자 세르게이 브린 아내와 불륜
# ZDNet Korea
#
#
#
# 김연아♥고우림, 3년 교제 끝에 10월 결혼
# 노컷뉴스
#
#
#
# 尹대통령 지지율 추락 7주 만에 '멈췄다'…여론조사 모두  …
# 시사저널
#
#
#
# 이상민 장관 "총경 집단행동, 지역 치안 책임자들이 이탈해 …
# 매일신문
#
#
#
# 박범계 "경찰국 사태, 2만 명이 들고일어나면 징계 못해"
# 조세일보
#
#
#
# ‘우영우’, 제2의 오징어게임 될까…해외도 주목 [IT클로 …
# 디지털데일리
#
#
#
# "연 8% 적금 나왔다" 카카오뱅크, 출범 5주년 맞이 ' …
# 머니S
#
#
#
# 김연아·고우림 '10월 결혼'...3년 열애
# 아이뉴스24
#
#
#
# Poland to buy jets, tanks, weapo …
# 코리아중앙데일리
#
#
#
# 이재용 “목숨 걸고”…삼성전자, 美 ‘260조원 투자계획’ …
# 이코노미스트
#
#
#
# BTS의 버터비치 녹이는 삼척석탄 멈춰라
# 한겨레21
#
#
#
# “구글 공동창업자, 머스크 회사 투자 정리 지시…아내와 불 …
# 블로터
#
#
#
# 진도서 막춤 광주서 '치콜', 이준석의 '장외정치' 뒤에는 …
# 주간조선
#
#
#
# [Photo News] Summer holidays at  …
# 코리아헤럴드
#
#
#
# '피겨퀸' 김연아, 성악가 고우림과 오는 10월 결혼 …
# SBS Biz
#
#
#
# 자고 싶지만 다리가 불안해서… ‘이 질환’ 의심해야
# 헬스조선
#
#
#
# '연금 환급' 내년엔 최대 연 148만원 받는다고 …
# 비즈니스워치
#
#
#
# 끝날 것 같았던 코로나 파도 얼마나 거세질까
# 시사IN
#
#
#
# 재테크 빙하기에 최고 6%…예적금 금리 짭짤한 곳은 어디?
# 매경이코노미
#
#
#
# ‘햇반 천하’에 도전장 낸 오뚜기와 하림, 즉석밥 시장판도 …
# 주간동아
#
#
#
# “학생 수 166만 ‘경기도 교육’ 바뀌면 다 바뀐다”
# 신동아
#
#
#
# '당뇨병' 예방 팁 10가지
# 코메디닷컴
#
#
#
# 몇 년씩 감금, 아이와 격리…이렇게까지 해야 하나?
# 일다
#
#
#
# 경계에 선 청춘의 험난한 취업 여정
# 주간경향
#
#
#
# [나홀로 세계여행] 몰디브는 비싸다? 선입견을 깬 히마푸시
# 월간 산
#
#
#
# "이 길로 학교 다니라고?" 대전 도마·변동지구 입주예정민 …
# 대전일보
#
#
#
# 일본 여성 자폐인 "'우영우', 살아도 된다는 용기 준 작 …
# 여성신문
#
#
#
# 끝 모르던 대통령 지지율 하락세 둔화..."사적채용 논란  …
# 국제신문
#
#
# 동영상기사
#
# [영상] 무더위 잊게 해 줄 제천의 2가지 비경
# CJB청주방송
#
#
# 동영상기사
#
# 전북도내 코로나19 연일 '2천 명대'.. 확산세 계속
# 전주MBC
#
#
#
# [속보] 이상민 "경찰서장 모임 위법성 엄정조사" 총경회의 …
# 강원도민일보
#
#
#
# WHO, 원숭이두창 '비상사태' 선포..코로나19 이후 2 …
# JIBS
#
#
#
# 밤새 대구 수성구 일대 정전···무더위 속 300여 가구  …
# 대구MBC
#
#
#
# WHO, 원숭이두창 '비상사태' 선포..코로나19 이후 2 …
# JIBS
#
#
#
# 밤새 대구 수성구 일대 정전···무더위 속 300여 가구  …
# 대구MBC
#
#
#
# 또 일가족 극단 선택..'도박빚에 생활고' 유서 발견
# kbc광주방송
#
#
#
# [양산] 젊은층에게 사랑받고 싶은데…“지드래곤이 써주면 안 …
# 농민신문
#
#
#
# 에어컨 없이 여름밤 보내는 몇 가지 방법에 대해
# 레이디경향
# 권성동 "경찰 집단행동, 배부른 밥투정" 맹비난 [경찰국 설치 논란]
# 권성동 “반드시 책임 뒤따를 것” vs 우상호 “경찰장악 맞서 싸우겠다”
# [뉴스1 PICK]윤 대통령이 가리키는 이 그림…발달장애 예술가 작품
# [포착] ‘하늘에서 화산재가 비처럼’…日 화산 분화, 최고 경보 발령(영상)
# 머스크, 구글 공동창업자 아내와 ‘잘못된 만남’
# TSMC 보란듯…삼성 세계 첫 ‘3나노’ 파운드리 출하
# 포스코그룹, 비상경영체제 돌입
# 토지 매매도 얼어붙었다…상반기 거래량 전년대비 27% 감소
# “IT로 사회 지속가능성 기여”… 카카오, 국내 첫 ‘기술윤리위원회’ 설치
# LGU+ 5G·LTE 프리미어 레귤러 가입시 `티빙` 무료
# 이상민 "경찰은 무장가능 조직…쿠데타가 이렇게 시작"(종합)
# 이상민?“경찰 집단행동 쿠데타 준해, 대단히 부적절”…권성동 “경찰, 배부른 밥 투정”(종합)
# 윤희근 경찰청장 후보자 “총경회의 참석자, 감찰 후 상응 조치할 것”
# 드라마가 현실로?… 우영우 팽나무 천연기념물 조사나선 문화재청
# 김연아 10월 결혼한다…신랑은 5살 연하 성악가 고우림
#
#
#
#  서비스 안내
#  고침 기사 모음
#  정정·반론·추후 보도 기사 모음
#  불공정 선거 보도 기사 모음
# 서비스 안내더보기

# %% [markdown]
# #### 과제0725_1
# 상기 출력물을 불필요한 공백없이 정렬하여 출력하세요.

# %%
items = bs.find('div',id='header').find_all('a')
for item in items:
    print(item.get_text())
# Out:
# 메인 메뉴로 바로가기
# 본문으로 바로가기
# 검색
# NAVER
# 뉴스
# TV연예
# 스포츠
# 날씨
# 프리미엄
# 언론사별
# 정치 선택됨
# 경제
# 사회
# 생활/문화
# IT/과학
# 세계
# 랭킹
# 신문보기
# 오피니언
# TV
# 팩트체크
# 전체 언론사
# 뉴스스탠드
# 라이브러리
# 전체 언론사
# 뉴스스탠드
# 라이브러리

# %%
texts = bs.find_all('p')
for t in texts:
#     print(t.string)
    print(t.get_text())
# Out:
# AiRS추천으로 구성된 뉴스를 제공합니다.
# 오전 11시~오후 12시까지 집계한 결과입니다.
# 본 콘텐츠의 저작권은 제공처 또는 네이버에 있으며 이를 무단 이용하는 경우 저작권법 등에 따라 법적책임을 질 수 있습니다.

# %%
import urllib.request as rq
import re
url = 'https://news.naver.com'
html = rq.urlopen(url)
bs = BeautifulSoup(html, 'lxml')
bs = bs.text
# bs
p = re.sub('[^가-힣]',' ',bs)
p = re.sub('\s{2,}',' ',p)
p
# Out:
# ' 네이버 뉴스 본문 바로가기 뉴스 연예 스포츠 날씨 프리미엄 검색 언론사별 정치 경제 사회 생활 문화 과학 세계 랭킹 신문보기 오피니언 팩트체크 전체 언론사 뉴스스탠드 라이브러리 콘텐츠 월 전체 언론사 뉴스스탠드 라이브러리 언론사편집 기자 연재 구독설정 서울신문 월 일 구독 공식 김연아 세 연하 포레스텔라 고우림과 월 결혼 년 열애 피겨여왕 김연아 가 크로스오버 그룹 포레스텔라 멤버 고우림 과 월 결혼한다 고우림 소속사 비트인터렉티브 측은 일 공식 보도자료를 통해 고우림이 오는 월 김연아와 결혼식을 올린다 고 밝혔다 시사저널 월 일 구독 오르는 금리 떨어지는 집값 영끌족 상환 부담에 비상 영끌족 대출금리 월부터 원리금 만원 부담 전체 가계대출 중 세대 비중 대보다 높아 대출금리가 포인트나 올랐습니다 대 남성 씨는 년 경기 시사 월 일 구독 끝날 것 같았던 코로나 파도 얼마나 거세질까 썰물의 시간이 지나고 밀물의 시간이 돌아왔다 월 중순 하루 만명으로 정점을 찍은 뒤 줄어들던 신규 확진자가 주 만에 상승세를 나타냈다 기울기는 제법 가파르다 월 첫째 주 주간 일평균 확진자 수는 약 지디넷코리아 월 일 구독 일론 머스크 구글 창업자 세르게이 브린 아내와 불륜 일론 머스크 테슬라 최고경영자 가 친한 친구이던 세르게이 브린 구글 공동창업자의 아내와 불륜을 저질렀다고 월스트리트저널 이 일 현지시간 보도했다 보도에 따르면 세르게이 브린은 지난 월 아내 니 기자협회보 월 일 구독 전 노조위원장 조합비 억 횡령 전임 노조위원장이 억원대의 조합비를 횡령한 사실이 뒤늦게 드러났다 현 노조 집행부는 고소장을 제출하는 등 민형사상 책임을 묻는 작업에 착수했다 신호 전국언론노조 지부장은 일 사내 공지를 통해 새로보기 강원일보 월 일 구독 김건희 여사 팬클럽 건사랑 회장 강신업 변호사 이준석 성상납 의혹 기업인 변호 맡아 윤석열 대통령의 부인 김건희 여사의 팬클럽인 건사랑 회장 출신인 강신업 변호사가 국민의힘 이준석 대표에게 성상납을 한 의혹으로 경찰 조사를 받는 김성진 구속 수감 아이카이스트 대표 변호인으로 선임됐다 강 변호 월 일 구독 겨울을 기다리는 푸틴 에너지 위기 어쩌나 노르트스트림 운영은 재개됐지만 공급량은 반쪽에 불과 당초 우려에도 불구하고 중단되었던 러시아 유럽 가스관 노르트스트림 을 통한 가스공급이 지난 일 재개되었습니다 정기점검을 위해 노르트스트림 이 월 한국경제 월 일 구독 만원 넘게 줬는데 부모님 집 에어컨 설치 논란 에어컨
세대 그랜저 대기만 벌써 만명 현대차 그랜저의 완전변경 모델 세대 그랜저 출시 시점이 올해 분기로 예견되는 가운데 이를 사겠다는 소비자가 벌써 만명을 넘은 것으로 알려졌다 일 현대차에 따르면 글로벌 차량용 반도체 품귀현상 등 코로나 주간조선 월 일 구독 김연아 연하 성악가 고우림과 결혼 년 열애 어떻게 숨겼나 한국 스포츠계의 슈퍼스타 김연아가 오는 월 살 연하 성악가와 결혼한다 김연아의 매니지먼트사인 올댓스포츠는 일 보도자료를 통해 김연아가 월 하순 서울 모처에서 성악가 고우림 과 화촉을 밝힌다 미디어오늘 월 일 구독 국민의힘 수신료 폐지주장에 비전문가적 주장 비판한 노조 프랑스가 수신료 폐지를 결정하면서 국민의힘과 조선일보가 논평과 기사로 공영방송 수신료 폐지를 다시 꺼내들며 를 압박했다 그러자 보수성향의 노동조합이 언론노조 세력만 키워주는 오판 이라며 국민의힘의 연합뉴스 월 일 구독 동영상 재생시간 윤대통령 지지율 하락세 주춤 긍정 부정 여론조사업체 리얼미터의 정례 조사에서 윤석열 대통령의 국정수행 지지율 하락 폭이 둔화했습니다 리얼미터가 지난주 실시한 여론조사 결과를 보면 윤 대통령 국정 수행에 대한 긍정 평가는 부정 평가는 매일신문 월 일 구독 이준석 성상납 의혹 기업인 변호인 교체 김건희 팬카페 회장 강신업 변호사 선임 이준석 국민의힘 대표에게 성상납을 한 의혹으로 경찰조사를 받는 김성진 아이카이스트 대표가 변호인을 교체했다 김건희 여사 팬클럽인 건희사랑 회장으로 이 대표에 연일 날을 세우고 있는 강신업 변호사가 새로 선임됐다 새로보기 세계일보 월 일 구독 이상민 경찰회의 해산명령 위반 상관명령 불복종 쿠데타 준해 이상민 행정안전부 장관이 경찰국 신설에 반대하며 지난 일 열린 전국 경찰서장 회의에 대해 일 하나회의 쿠데타에 준하는 상황으로 대단히 부적절하다 고 비판했다 검사들의 집단 반발은 되고 경찰회의는 문화일보 월 일 구독 김연아 포레스텔라 고우림과 월 결혼 다섯 살 많은 연상연하 커플 년 아이스쇼서 처음 만나 년간 교제끝 부부의 연 맺어 데이트 사진 공개직후 발표 피겨여왕 김연아 왼쪽 사진 가 오는 월 크로스 ...

# %%
import urllib.request as rq
import re

url= 'https://news.naver.com'
html = rq.urlopen(url)
bs= BeautifulSoup(html,'lxml')
texts = bs.find_all('p')
for t in texts:
#     print(t.string,'\n')
    print(t.get_text(),'\n')
# Out:
# 포레스텔라 고우림(왼쪽, SNS), 김연아(뉴스1 DB) © 뉴스1(서울=뉴스1) 고승아 기자 = 전 피겨스케이팅 국가대표 선수 김연아(32)와 그룹 포레스텔라 멤버 팝페라 가수 고우림(27)이 깜짝 결혼 소식을 알렸다.고우림 소속사 비트인터렉티브는 25일 공식입장을 내고 "고우림은 오는 10월 김연아와 결혼식을...
#
# '피겨 여왕' 김연아(32)가 그룹 포레스텔라 멤버 팝페라 가수 고우림(27)과 결혼한다. 25일 김연아의 매니지먼트사 올댓스포츠는 "김연아가 오는 10월 하순 서울 모처에서 성악가 고우림과 화촉을 밝힌
10월 하순 서울 모처에서 성악가 고우림(27)과 화촉을 밝힌다”고 밝혔다. 김연아의 피앙세인 고우림은 서울대
#
# '피겨퀸' 김연아(32)가 오는 10월 결혼합니다. 김연아의 매니지먼트사인 올댓스포츠는 오늘(25일) "김연아가 10월 하순 서울 모처에서 성악가 고우림(27)과 화촉을 밝힌다"고 밝혔습니다. 올댓스포츠는 "김연아와
#
# 담도암 5년 생존율은 꼴찌(췌장암)에서 2등이다. 10명 중 3명만 산다. 꼴찌가 아닌 탓인지 담도암은 비교적 잘 알려지지 않았다. 다른 나라보다 우리나라에서 호발(好發)하는 암인데도 말이다. 증상이 잘 안 나타나기
#
# 체스 로봇이 지난주 열린 국제체스대회에서 대국 도중 상대편 아이를 공격해 손가락을 부러뜨렸다. 24일(현지시간) BBC는 지난 19일 러시아 모스크바 국제체스포럼에서 진행된 인간 대 로봇 체스 경기에 참가한 7세 소
#
# 현대차 그랜저의 완전변경 모델 '7세대 그랜저' 출시 시점이 올해 4분기로 예견되는 가운데 이를 사겠다는 소비자가 벌써 3만명을 넘은 것으로 알려졌다. 25일 현대차에 따르면 글로벌 차량용 반도체 품귀현상 등 코로나
#
# 전국 경찰서장 회의에 참석했다가 대기발령 조치를 당한 울산중부경찰서장 류삼영 총경이 "휴일에 정당한 절차를 거쳐 세미나 형식을 회의를 한 것에 대한 징계는 부당하고 해당 모임에 대해 강제해산 명령은 오히려 직권 남용
#
# 6년 전 전석 매진작 배우·제작진 귀환 전무송·박정자·손숙 등 대배우들 조연 3040 젊은 배우들이 주연 맡아 현대적 외피 두른 정통극...배우들 열연 빛나 '여성혐오' 지적 받는 원작 속 가부장 사회 수동적인 여성
#
# 임태희 경기도교육감 ● 13년 만에 첫 경기도 보수 교육감 ● 3선 의원·노동부 장관·대통령실장·대학총장 관록 ● 교부금 개편 논쟁, 절충안 있다. ● 혁신학교에서 몽실학교까지 평가 후 재정비 ● 9시 등교 폐지가
#
# Poland's defense minister said his country plans to buy 48 FA-50 fighter jets, a first installment of 180 K-2 tanks and
#
# 금융위원장이 청년 특례 채무조정 제도를 설명하면서 “조금 더 따뜻한 마음으로 이해해주고 도와주려는 마음을 가지길 바란다”고 요청했고, 대통령은 이른바 영끌과 빚투에 몰린 청년들을 언급하며 “어려울 때 두텁게 안아주는
#
# 일론 머스크 테슬라 최고경영자(CEO)가 친한 친구이던 세르게이 브린 구글 공동창업자의 아내와 불륜을 저질렀다고 월스트리트저널(WSJ)이 24일(현지시간) 보도했다. 보도에 따르면 세르게이 브린은 지난 1월 아내 니
#
# 금호타이어가 25일 폭스바겐의 '전략 차종'인 제타(ZETTA) 7세대 페이스 리프트 차량에 신차용 타이어(OE)를 공급한다고 밝혔다. 2022년형 제타 페이스리프트는 지난해 3분기 출시됐다. 북미와 아시아 시장을
#
# #. 지난 4월 철거공사를 끝낸 서울 용산의 한 다세대주택(빌라). 건물 4개를 허문 자리에 각종 폐기물이 방치된 채로 공사장 인부들은 물론 포클레인 등 공사 장비가 3개월째 자취를 감춰버렸다. 건축비 상승으로 공사
#
# 행정안전부 경찰국 신설에 반대해 전국 경찰서장 회의를 주도한 류삼영 총경이 대기발령 조치를 받자 일선 경찰들이 "나도 징계하라"며 크게 반발하고 있습니다. 유근창 경남 마산동부경찰서 양덕지구대장은 오늘 오전 경찰 내
#
# 여론조사업체 리얼미터의 정례 조사에서 윤석열 대통령의 국정수행 지지율 하락 폭이 둔화했습니다. 리얼미터가 지난주 실시한 여론조사 결과를 보면, 윤 대통령 국정 수행에 대한 긍정 평가는 33.3%, 부정 평가는 63.
#
# 행정안전부 산하에 경찰국을 신설하는 문제를 두고 정부와 경찰이 갈등을 겪고 있는 가운데 여당 내부에서도 속도 조절이 필요하다는 의견이 나왔다. 하태경 국민의힘 의원은 25일 "대통령실도 그렇고 정부가 (경찰을) 너무
#
# 윤석열 대통령의 국정수행 지지율(긍정 평가)이 3주째 30%대에서 답보하고 있다. 이런 가운데, 윤 대통령에 대한 20대의 긍정 평가는 20%대까지 하락한 것으로 나타났다. 리얼미터가 지난 18∼22일 성인 2527
#
# 지지부진한 교육행정에 대전 서구 도마·변동지구 8구역 입주예정자들의 불만이 들끓고 있다. 내달 1일 입주 예정임에도 배정받은 초등학교의 통학로 개선 대책이 마련되지 않으면서 비판여론이 거세지는 모습이다. 24일 대전
#
# '영끌족', 대출금리 2.2%→5% "8월부터 원리금 150만원 부담" 전체 가계대출 중 2030세대 비중 27.5%…"50대보다 높아" "대출금리가 2.8%포인트나 올랐습니다." 30대 남성 A씨는 2020년 경기
#
# 나홀로 세계여행 인도양의 보석, 몰디브비행기에서 몰디브의 산호초 섬들을 보는 순간, 숨이 멎었다. 사진으로 보던 모습과는 비교도 되지 않았다. 바다에는 비취빛 에메랄드들이 반짝이고 있었다. 비행기가 멈추었으면 하는
#
# 일본 출입국관리소에 수용된 외국인 여성들을 만나온 오다 아사히(織田朝日) 씨는 출입국관리 체계와 수용시설의 문제점을 지적하는 활동을 하고 있다. 출입국관리 시스템에 의해 수용된 여성들의 실태를 오다 씨가 직접 전한다
#
# 페이스북‧인스타그램을 운영하는 메타가 다음달 9일 개인정보처리방침 및 이용약관을 업데이트한다. 이에 따라 페이스북과 인스타그램 이용자는 개인정보 수집‧이용 등에 대해 동의하지 않으면 서비스를 이
#
# '피겨 여왕' 김연아(32)와 팝페라 가수 고우림(27)이 결혼한다. 25일 두 사람의 열애 소식과 함께 고우림 소속사 비트인터렉티브는 이날 공식입장을 내고 "고우림은 오는 10월 '피겨여왕' 김연아와 결혼식을 올린
#
# 최근 국회에 담배 판매 영업소 간 거리를 기존 50미터 이상에서 100미터로 확대하는 내용의 담배사업법 개정안이 제출된 가운데 편의점업계는 당장 큰 영향이 없을 것이란 반응을 보이고 있다. 서울 등 대부분 대도시에서
#
# 기사내용 요약 크로스오버 그룹 포레스텔라 멤버 전 피겨스케이팅 스타 국가대표 선수 출신 김연아(32)가 5세 연하인 크로스오버 그룹 '포레스텔라' 멤버 겸 팝페라 가수 고우림(27)과 결혼한다. 25일 김연아 소속사
#
# 신종 코로나바이러스 감염증(코로나19) 확산에 대응해 각국의 봉쇄조치가 가장 활발하게 이뤄졌던 2020년 4월 세계적으로 교통량은 41% 가량 감소했다. 해양교통량과 항공교통량은 각각 9%, 75% 정도 줄어들었다.
#
# 윤석열 대통령의 부인 김건희 여사의 팬클럽인 '건사랑' 회장 출신인 강신업 변호사가 국민의힘 이준석 대표에게 성상납을 한 의혹으로 경찰 조사를 받는 김성진(구속 수감) 아이카이스트 대표 변호인으로 선임됐다. 강 변호
#
# "박지현은 은수저...담글수록 민주당 '독' 드러난다" '이재명 당선! (3월 9일엔) 승리의 밤이 왔으면 좋겠다.' 지난 2월 10일 <더팩트>와 인터뷰했던 '이재명의 영입 인재' 박지현은 간절했다. 윤석열 국민의
#
#
#
#
#
#                                 방송 모아보기 클릭 시해당 방송사 뉴스를 볼 수 있으며LIVE 표시가 된 경우 생중계로시청 가능합니다.
#
#
#
#
# 대구농수산물도매시장 '하빈 이전설'…현실화 가능할까?
#
# 대구농수산물도매시장 '하빈면 이전설' 떠올라
#
# "건축비 부담 크다" 매천시장 현대화 사업 암초
#
# 윤 대통령, 경찰 집단 반발에 "행안부·경찰청이 잘할 것"
#
# '경찰 장악' 논란에도...비서실장까지 등장 "서장회의 부적절"
#
# 대통령님, '전국 경찰들과의 대화' 어떠십니까?
#
# "검찰은 되고 경찰은 안 되나"... 류삼영 서장 징계 후폭풍
#
# [이슈앤 직설] 尹정부 "종부세 대폭 손질하겠다"…다주택자 "당분간 안 판다"
#
# [이슈분석] 다주택자 세 부담 '확' 낮춘 정부…시장에 미치는 영향은
#
# [김대호 박사의 오늘 기업·사람] 스냅·트위터·대우조선해양·삼성전자·스타벅스·이마트
#
# [택시의 나라, 모빌리티 잔혹사]④표심에 눈먼 정치권…기사들 삶 나아졌나요?
#
# [택시의 나라, 모빌리티 잔혹사]③ 해외는 '택시난제' 어떻게 풀고 있나
#
# [택시의 나라, 모빌리티 잔혹사]②'60세 이상 77%' 노쇠한 택시업…기사가 없다
#
# [택시의 나라, 모빌리티 잔혹사]①우버부터 타다·카모까지…택시에 막힌 혁신
#
# [아미랑] “여행을 떠나세요, 손을 잡으세요”
#
# [아미랑] 항암치료로 빠진 눈썹, ‘문신’해도 될까요?
#
# [아미랑] 폐암과 관련해 알아둘 유전자 상식
#
# [아미랑] “이별을 준비하는 가장 현명한 방법은…”
#
# 윤희근 경찰청장 후보자 "총경회의는 복무규정 위반…감찰후 상응조치"
#
# 이상민 "경찰서장회의는 하나회 12·12 구데타에 준하는 부적절한 행위"
#
# 윤 대통령, 경찰 반발 확산에  "행안부·경찰청서 필요조치 잘 할 것"
#
# 강원경찰 "정부 밀어붙이기 식 경찰국 설치 반대" 반발 고조
#
# [부동산 줍줍]원희룡의 경기도민 (교통지옥) 해방 일지
#
# [부동산 줍줍]둔촌주공 경매 위기 탈출!?(새 대주단은 비밀)
#
# [부동산 줍줍]둔촌주공, 합의? 끝날 때까지 끝난 게 아니다
#
# [주간 뉴스타파] 조작으로 쌓아올린 한동훈 처가의 '아이비 캐슬'
#
# 한동훈 처조카 논문 데이터 위조... 촛불집회에 다인종 참여?
#
# 통계 뒤죽박죽 베낀 엉터리 논문 수두룩... 한동훈 처조카 데이터 조작
#
# 미국 논문 쓰면서 '브라질 주민 데이터' 도용...한동훈 처조카 논문 데이터 위조
#
# 경찰 갈등은 ‘제2의 윤석열’ 싹 자르는 노림수?
#
# 현직 경찰이 이상민 장관에게 보내는 편지
#
# 경찰 시위에 행안부 “투명한 행정 위한 것”? [뉴스큐레이터]
#
# 시위 막던 경찰 시위
#
# "이기는 민주당 만들겠다"…광주서 의지 다진 이재명 [TF사진관]
#
# 7개 상임위원장 가져간 국민의힘, 미소짓는 권성동 원내대표 [TF사진관]
#
# '이렇게 반가울 수가' 권성동·오세훈 악수하며 함박웃음 [TF사진관]
#
# 우상호, "尹 정부, 과학 방역 큰소리치더니…'각자도생 방역' 됐다" [TF사진관]
#
# '슈퍼달러 펀치' 원/달러 환율 1400원 가나
#
# 환율 역사적 고점 때 '서울 아파트값' 얼마나 하락했나
#
# "IMF 외환위기 악몽 재현?"… 한·미 통화스와프 부활하나
#
# [WHY] No reservation needed at Korea's hottest dining spot — the convenience store
#
# [WHY] Jeonse, and the reason behind so many Koreans' choice to forgo monthly rent
#
# [WHY] Koreans' love-hate relationship with Samsung
#
# 뉴 앱노멀·초불확실 시대, 금융지식(FQ)부터 쌓아라 [국제경제읽기 한상춘]
#
# "첫 약세장 만난 美 Z세대 공격적 투자 지속"
#
# "美증시 약세 국면에 사야할 종목은 운송주와 금융주"
#
# 골드만삭스 "일부 태양광업체 어닝 서프라이즈 발표 예상"
#
# [EDITOR's LETTER] 편견을 걷어내면 보이는 다른 것
#
# [우영우 읽기] ‘권모술수’ 권민우와 ‘우당탕탕’ 우영우가 회사에서 사는 법
#
# ‘편견’을 넘어서며 발전하는 인류의 역사
#
# 초유의 경찰서장 회의에 징계 대응…내부 반발 격화
#
# 경찰국 신설 공방…"부적절한 집단행동" vs "공안통치"
#
# 김대기 비서실장 "부적절 행위…경찰도 견제 필요"
#
# 경찰국 반발 후폭풍…경감·경위도 집단행동 예고
#
# "쿠데타, 부화뇌동, 처벌"…이상민, 총경회의 '20분 맹폭'
#
# 尹, 경찰 집단행동에 "행안부·경찰청서 필요한 조치 할 것"(종합)
#
# 경찰직협, 서울역에서 전단지 돌리며 대국민 홍보전..."12·12 쿠데타 비판, 너무 많이 갔다"
#
# 우상호 "이상민, 경찰 쿠데타라고? 언어도단 적반하장"(종합)
#
# "문 닫아놓으면 손님 줄고 코로나도 걱정"... 종로·홍대 등 가게 80%가 문 열고 냉방중 [현장르포]
#
# 빚투 탕감… "도덕적 해이 부추겨" vs "회생제도 취지 맞다" [법조 인사이트]
#
# 재활용되는 캡슐커피, 소비자 41%는 그냥 버려 [지구를 사랑하는 장한 나]
#
# 회식보다 무서운 택시대란.. '탄력요금제' 하면 택시기사들 돌아올까
#
# 대우조선 적자·파업 수렁…22년 채권단 체제 사실상 실패
#
# "밑빠진 독…대우조선 원점서 검토를" [뉴스&분석]
#
# 대한항공·아시아나 '항공 빅딜' 난항…HMM 매각도 불투명
#
# 대우조선 사태 봉합…정부 "불법 책임묻겠다"
#
# 尹정부, '120대 국정과제' 확정 "기득권 저항에도 개혁 꼭 필요"
#
# 문체부 첫 업무보고 실종된 '게임'…"주무부처 바꿔야" 목소리도 [IT돋보기]
#
# 과기정통부, 위원회 절반 없앤다
#
# [과기정통부 업무보고] 8월 범정부 '디지털 국가전략' 수립
#
# ‘모였다고 징계’…검찰정권의 짙어지는 경찰 군기잡기
#
# 7월 25일 한겨레 그림판
#
# [사설] ‘경찰 장악’ 예고편 보여준 총경회의 참가자 징계
#
# 국힘 “엄정 대처”, 민주 “전두환식”…여야 경찰총경 회의 상반 반응
#
# 석유 한 방울 안 나는데… ‘기름진 사회’ [연중기획 - 지구의 미래]
#
# 화석연료와의 결별은 가능할까 [연중기획 - 지구의 미래]
#
# 서민부담 앞세워 ‘유류세 인하’ 땜질만… 탈화석연료 역행 [연중기획-지구의 미래]
#
# “탄소중립 시계 늦춰라”… 글로벌 석유사들 몸부림 [연중기획-지구의 미래]
#
# [일문일답] 이상민 "경찰국 적법…서장회의 대단히 위험한 행위"
#
# 윤희근 "총경회의는 복무규정 위반…감찰후 상응조치"
#
# 권성동 "경찰 집단행동, 배부른 밥투정…반드시 책임 따를 것"
#
# 우상호, 이상민 '쿠데타' 언급에 "언어도단에 적반하장"(종합)
#
# [사설] 어떤 경우에도 정부·경찰 정면 대결 안 된다
#
# [박정호의 시시각각] 무지갯빛 ‘우영우’는 있을까
#
# [김병필의 인공지능 개척시대] 진짜 같은 가짜 데이터로 인공지능 가르치기
#
# [분수대] 깻잎 논쟁
#
# 낸드 가격하락에 ‘칩4’ 압박까지… 하반기 ‘반도체 한파’ 닥치나
#
# 반도체발 수도권 정원 증가 8000+α… 대입 판도 흔드나
#
# 경기, 판교밸리·용인플랫폼시티에 ‘반도체 클러스터’ 구축
#
# [인터뷰] 영화 ‘브로커’ 칸 트로피 뒤에 변호사들 있었다… “韓 영화 국제화로 법률 자문↑”
#
# [인터뷰] 제임스 콘웨이 하시코프 부사장 “韓 클라우드 급성장하는 시장… 투자·고용 지속 확대”
#
# [인터뷰] 가상자산 분석업체 쟁글 대표 “주식 수준으로 정보 공개해야”
#
# [인터뷰] 尹 인수위 출신 주현철 변호사 “가상자산 업계는 방치 수준”
#
# 美 6월 소비자물가 9.1% 상승,  41년 만에 최고치 찍었다
#
# ‘1만3000원의 행복’ 돈값 하는 냉면 맛집
#
# 中 신형 항모 ‘푸젠’, 스펙 뜯어보니 ‘빛 좋은 개살구’
#
# 리츠도 줄줄이 신저가, 신규 진입자에겐 또 다른 기회
#
# [NOW] TV수신료 폐지안 프랑스 하원 통과
#
# 英·佛 “수신료 폐지” 日 “10% 인하”… 한국은 인상 추진
#
# 방만 경영 개선않는 KBS… 수신료 폐지 운동 거세져
#
# 정권 바뀔 때마다 시끄러운 공영방송
#
# [원자잿값 추락]슈퍼사이클 꺾였다…"경기둔화 수출기업 직격탄"(종합)
#
# [원자잿값 추락]철광석 100弗 아래로…철강업계, 위기 경영 돌입
#
# [원자잿값 추락]역대급 실적 누리던 정유사들…유가 하락에 '악'
#
# 유가 하락 베팅 한 달 만에 웃었다…"유가 약세장 논하기 일러"
#
# [대한민국 대전환 'ON'] 프랑스, 사용후핵연료 '재처리' 세계 최대
#
# [대한민국 대전환 'ON'] 佛 오라노 수석부사장 "원전 재처리, 자원 아끼는 방안"
#
# [대한민국 대전환 'ON']우리나라 사용후핵연료 처리 계획은
#
# “한국, 에너지 전환시 최대 86만개 일자리 창출”
#
# [연료 떨어진 배민]①'글로벌 진출' 오히려 독됐나
#
# [연료 떨어진 배민]②줄어든 파이, 성장세 유지할 수 있을까
#
# [연료 떨어진 배민]③퀵커머스 먼저 열었지만 치고 나가지 못한 B마트…왜?
#
# [약손+] 물⑥ 하루에 물 3리터씩 마셔봤더니···
#
# [뉴스+] "홍준표 시장의 20일, 위험천만하다"
#
# [달려보니] ⑥대구 하중도(금호꽃섬)-내일을 향해 달려가는 코스
#
# [뉴스+] 대구시의회 '청부입법' 논란, 왜?
#
# TSMC 보고 있나…삼성전자, 3나노 파운드리 출하식 개최 [박신영의 일렉트로맨]
#
# 4000년 전 흙판에 써있다…"아빠 노릇하려면 선물 보내요" [성수영의 그때 그 사람들]
#
# 위메프 前대표가 만든 스타트업, 130억원 모았다 [김종우의 VC 투자노트]
#
# '페니(10원) 전쟁' 승부수 던진 美유통업계 [김리안의 글로벌컴퍼니]
#
# 안철수 작심토로 “블랙리스트, 백현동? 정치보복 소리 듣기 싫어 봐주는 게 최악”
#
# 아베 신조는 정말 ‘극우’였을까
#
# “아이들이 아빠가 왜 죽었는지는 알아야죠”
#
# 다시, 김호중의 시간
#
# 임차인 세 부담에 임대시장도 세제개편
#
# 세제개편으로 줄어든 세수 ‘13조원’…기재부, 예산편성 고삐 죈다
#
# 또 '부자 감세' 프레임…野, 보수 정권 세제개편 발목잡기
#
# 전경련 “세제개편안, 기업 투자·일자리 창출 도움 기대”
#
# 출근카드가 꼭 직원의 성실성을 보여주는 건 아니다
#
# 페이스북 광고 위한 개인정보 강제 수집, 법적 문제는?
#
# 논란의 권성동 '9급 공무원' 발언은 어떻게 언론에 드러났나
#
# 모든 호수 벨 누르며 "절단된 채 살아남은 김용균들"을 찾다
#
# 이상민 "경찰서장회의, 쿠데타 준하는 상황...대단히 부적절"
#
# [현장영상+] 尹 "경찰 집단 행동, 행안부·경찰청서 필요한 조치할 것"
#
# 우상호 "경찰 장악에 비서실장 등판...尹 지시로 해석"
#
# 권성동 "경찰 집단행동, 정치세력화...책임 뒤따를 것"
#
# [영상] 국비 발목 잡힌 오륙도 트램…4년째 첫 삽 못 떠
#
# [영상] 한일 갈등에 EEZ 황금어장 잃었다…한숨 쉬는 수산업
#
# [60초 뉴스]‘반도체 동맹’ 할까 말까? 국내 반도체 업계 고심
#
# 갑작스러운 심장 두근거림... 부정맥 신호?
#
# ‘우영우’, 제2의 오징어게임 될까…해외도 주목 [IT클로즈업]
#
# 中 '우영우' 도둑시청하며 호평?…평점 9.3에 팬계정까지 등장
#
# 中 '우영우' 도둑시청에 분노…"중국 당국이 나서라"
#
# 두 자릿수 시청률도 돌파한 '이상한 변호사 우영우'... 제작사 주가는?
#
# [양산] 젊은층에게 사랑받고 싶은데…“지드래곤이 써주면 안되나요?”
#
# [우산&양산] 단순한 ‘햇빛 가리개’ 아니에요…멋 더해주는 ‘개성만점’ 패션템
#
# 최상급 한지와 대나무로 만든 ‘왕의 우산’…수려함에 젖어들다
#
# [우산&양산] 돈 아까워 우산 고치나? 소중한 추억 때문에 그렇지
#
# 국회 18개 상임위원장 한 자리도 못 차지한 충청권
#
# 수년째 셋방살이에 수십억 혈세… 세종시 별관증축은 언제쯤
#
# '똘똘한 한 채'에 올인… 대전 부동산 매도심리 1년새 9배나
#
# 원숭이두창 증상도 '변이'… "성병으로 오인 가능성"
#
# [세계를 보다]에어컨 없는 런던이 40도…펄펄 끓는 지구
#
# [현장 카메라]물고기 싹쓸이…골칫덩이 된 가마우지
#
# [세계를 가다]사룟값 폭등…美서도 “반려동물 포기”
#
# [사건을 보다]동남아 마약왕 ‘사라 김’…3년 만에 현지 검거
#
# [뉴스야?!] 이재명도 기소되면 대표 박탈?
#
# [포커스] 대법원·헌재, 잇단 '충돌'…최고 사법기관 힘겨루기?
#
# [따져보니] "젊을수록 재감염 잘된다?"…재감염·첫 감염 비교하니
#
# [뉴스7 취재후 Talk] '국민간식' 은 옛말…어쩌다 배달 치킨 3만원 시대
#
# 다시 크런치모드? IT노동자들 긴장하는 까닭[그래?픽!]
#
# [법정B컷]경찰수사 잘했더라면 엄마는 죽지 않았을까…大法, 국가 책임 인정
#
# '인력난' 말하면서 '임금 인상'은 못한다는 조선업계, 왜?[노동:판]
#
# [노컷체크]대한민국이 인신매매 방지 '2류 국가'?
#
# 코로나 검사·진료·처방 원스톱 병원 쉽게 찾으려면?
#
# "코로나19 감염 후 면역 20개월 지속...재감염시 위험 낮아"
#
# "오미크론 감염됐다면 지금 유행 코로나 덜 걸려"
#
# 수도권 쏠림 "불 보듯".. 반발 확산
#
# 적기 일손 공급.. 농가 만족도 높아
#
# 쿠팡 유치 왜 무산됐나.. 책임론 확산
#
# 지방의회 이해충돌방지법 '뒷전' 논란
#
# [2022 필즈상] 필즈상은 어떤 상인가
#
# [2022 필즈상]사상 두 번째 여성 필즈상 수상자 배출…다른 세 명의 수상자들
#
# [한국계 첫 필즈상 수상] 허준이 교수는 누구인가
#
# [한국계 첫 필즈상 수상] 허준이 교수 "수학은 '자유로움'을 학습하는 일…얽매이지 않고 생각해야"
#
# 다양성 갖춘 새로운 시도들그동안 없었던 클래식 무대
#
# 이혜연 "농구선수 출신 고졸여성이 은행 지점장까지 된 비결요? ...버텨야 한다는 간절함 때문 ... 나를 믿어야 얻을 수 있더군요"
#
# [메트로폴리탄 뉴욕]중세풍 유리램프 만들고백악관 인테리어 도맡아명품 주얼리 ‘티파니’ 뜻밖의 도전史
#
# “우울감·스트레스 심리치료 시스템 우선”
#
# [D:리포트] 당신은 볼 수 없었던 그들의 쉴 곳
#
# [크로스체크] '판스프링' 사람 죽고 다쳐도 '가해자'는 없다
#
# [D:인사이드] 청년들이 상처를 받았다면 '사과' 드린다
#
# [밀착카메라] 타결 전까지 팽팽했던 긴장감…거제는 이제 달라질까
#
# [스쿨존 점검]③ 스쿨존이 님비시설? 어린이 안전과 맞바꾼 주차 편의
#
# ‘저임금 노동’에 ‘100억 적자’ 따릉이…“나 계속 달릴 수 있죠?”
#
# “명령 불복종”에 “후보자 사퇴” 맞불…거센 반발 배경은?
#
# 청소노동자 집회, 대학가의 진짜 생각은?
#
# 부동산 세금 어떻게 바뀌나…1주택자 재산세 공시가격에 희비 엇갈려
#
# 국민 숨통 트인다…다주택자 稅 폭탄 시대 끝났다
#
# 2주택자 기존 주택 팔아 취득세 절약…자녀 ‘부담부 증여’ 양도세 절세 효과
#
# 빠르면 4년 만에 아파트 단지 뚝딱…모아타운 투자 가치는?
#
# 22년차 '퀴퍼질'…"이 짓을 왜 하냐고? 외롭지 않으려고"
#
# '퀴어퍼레이드 고인물' 레즈비언 바 사장이 만드는 '공간'
#
# 빗속에 핀 무지개…퀴어로 채운 서울광장
#
# ‘경찰국 반대’ 총경 집단 행동 갈등 격화
#
# “참석자들 감찰 착수” “총경 응원 모금운동”… 강 대 강 대치
#
# 우연? …국힘-경찰 갈등 중심에 또 ‘울산’
#
# 이번엔 ‘공직사회 리더십’ 시험대 윤 정부, 또 ‘압박·설득’ 투트랙 가나
#
# 대우조선 1독 진수작업 5주 만에 재개, 금속노조 탈퇴 등 勞勞갈등은 불안요소
#
# 거제 상인들 “큰 걱정 덜어” 타결에 안도
#
# 대우조선, 8000억 손실 남긴채 파업 ‘매듭’
#
# ‘불법파업은 책임 문다’는 학습효과 필요 [기자의 눈/이건혁]
#
# 尹 대통령 지지율 30% 붕괴 '눈앞'.. 긍정 평가 30.4%
#
# "尹대통령 잘못한다" 64.2%..보수층도 돌아서
#
# 尹, 사적채용 '부적절 65.5%..40대男·20대女 80%↑'
#
# 민주당 차기 당 대표 이재명 41.8%..전주대비 3.2%↑
#
# [기획] 직장인 소득세 최대 80만원 줄어든다
#
# [2022 尹정부 세제개편안] 과표 5억 기업 법인세 3000만원 절감효과… 통합고용세액공제 신설
#
# [2022 尹정부 세제개편안] 연금저축·퇴직연금 세액공제 확대… 납입한도 700만원→900만원
#
# [2022 尹정부 세제개편안] 종부세 기본공제 9억… 다주택 중과 폐지
#
# [영상] 폭락한 윤석열 지지율 끌어올리는 방법 알려드림 [정치왜그래?]
#
# [영상] 아베 피격 사망, 평화 헌법 개헌된다고? [정치왜그래?]
#
# 박지현  “민주당은 고인 물, 계속 돌 던지겠다” [정치왜그래?]
#
# 행안부 장관 “경찰 내 특정그룹이 ‘경찰국’ 반발 주도 의심”
#
# 류삼영 전 울산중부서장 대기발령 후 첫 출근일에 ‘휴가’
#
# 권성동 “경찰 집단행동은 배부른 밥투정, 정치세력화”
#
# 윤 대통령, 경찰 집단행동 “행안부·경찰청 필요한 조치할 것”
#
# [신선한 경제] 예적금 '껑충'‥금리상한형 대출 폭증
#
# [신선한 경제] 가장 큰 수혜는 연봉 1억 안팎 소득층
#
# [신선한 경제] 스타벅스, 유해물질 검출 의혹 '서머 캐리백' 교환
#
# [신선한 경제] '서울사랑상품권' 500억 추가 발행‥7% 할인
#
# 경찰 집단행동 확산…행안부 개입 의혹까지 ‘일파만파’
#
# ‘경찰국 신설’ 반발 확산에 尹대통령 “지켜보고 있다”
#
# 경찰청장 후보자 “경찰서장회의 해산명령 불이행…조치할 것”
#
# [사설] 경찰국 반발 집단행동, 정치권 갈등증폭보다 수습책을
#
# [뉴스돋보기] '경찰국 후폭풍' / 이재명 대항마는? / 윤석열의 그 노래
#
# [인터넷 와글와글]'킥보드 질주'/쥐가 비둘기 사냥
#
# [뉴스추적] 원숭이두창 치명률 3~6%? 국내 유행 가능성?
#
# "분당? 호사가들의 이야기일 뿐 가능성 없어" 윤건영 더불어민주당 의원 직격인터뷰 [시사스페셜]
#
# 하나금융, 상반기 순이익 1.7조원…전년 동기 대비 1.5%↓
#
# 우리금융, 올 상반기 순익 1조7610억원…반기 최대 실적 냈다
#
# 신한금융, 올 상반기 순익 2조7208억 '역대 최대'…은행·카드사 선전
#
# WHO, 원숭이두창 '비상사태' 선포..코로나19 이후 2년여  만
#
# 그 시절 소년, 다시 '제주 해녀'와 뭍에 오르다.."몰입 전시로 만나볼까"
#
# 국내 미기록종 '산다시마이끼' 제주서 첫  발견
#
# 日 원전 오염수 방류 이르면 내년..어민들 '삼중고' 호소
#
# 중첩·얽힘 이용하는 양자컴... 속도가 기하급수로 증가
#
# "반도체와 양자기술 동시에 잡으려면 재교육 투자해야"
#
# "한국은 하드웨어 강조하지만... 양자컴 시대에도 소프트웨어가 핵심"
#
# Will secretaries be replaced to rebound Yoon’s approval rating?
#
# Yoon calls for end to DSME disruption
#
# S. Korea targets W340tr investment for chip supremacy
#
# 與, 경찰 내 '경찰국' 반대에 "조직 이기주의이자 불법"
#
# 우상호 "장관 수사지휘는 전두환식…이상민 인권의식 이정도?"
#
# 이상민 장관 "경찰서장 회의는 12·12쿠데타에 해당하는 범죄"
#
# 尹대통령, 경찰 집단행동 예고에 "행안부·경찰청이 조치 잘할 것"
#
# [뉴스쉽] 코로나에 고환율에…해외여행 갈 수 있는 거야?
#
# [그사람] 'K-에듀'를 꿈꾸는 사교육 총수, 손주은
#
# [사실은] 국회의원 토론王은 누구일까요?
#
# [취재파일] 구의원님, 산하기관 생수 납품이 떳떳한가요?
#
# 물가 78% 뛰고 화폐가치 역대 최저…대통령이 통화정책에 개입한 결과 [조지원의 BOK리포트]
#
# 골드만삭스 "메타·GE 등에 콜옵션 전략 효과적일 것"[서학개미 리포트]
#
# "서울경제 유튜브 채널 '어썸머니'서 매주 美 투자전략 알려드려요"
#
# 금리 인상기, 앱으로 ‘짠테크’ 한다…'손품' 팔아 금리 낮은 곳 찾고, 걸어서 포인트 쌓고
#
# 매출 불씨 꺼지지 않도록… 최대 3억 특례보증·6개월마다 금리 선택
#
# 소득세 감면 최대 수혜자는 ‘1억 안팎 연봉자’
#
# 추경호 “안심전환대출로 내년 변동금리 비중 5%P 낮출 것”
#
# 끝모를 지지율 하락…尹, MB의 길 선택하나
#
# 尹, 보수층도 등 돌렸다…"국정동력 타격 심각"
#
# “경제 올인은 기본..尹대통령 언행부터 신중해져야”
#
# 두 달간 내파된 집권 여당…尹정부에 오히려 악영향
#
# [단독] 대중교통·학교서 모르는 여성 노려...'정액 테러' 절반은 집행유예
#
# 마시던 커피·택배에 '정액 테러', 성범죄로 처벌 못한다?
#
# "한국 성범죄자들, 법 허술해 엄벌 피해" 외신도 '정액 테러' 조명
#
# 정액테러·메타버스 성추행도 '성범죄'...처벌법 만들어야
#
# [ASMR] 소리로 맛보는 2대를 이어온 올갱이
#
# 내륙의 바다, 청풍호의 비경
#
# 충북대병원의 실험 '검사료 후불제' 먹튀는 없었다
#
# 예민보스 반려견과 여름 휴가 떠날 계획이라면?
#
# “무력수단 가진 집단의 하극상”… 정부, ‘警亂’ 에 초강경 대응
#
# 이상민 “경찰서장회의, 쿠데타 준하는 상황”
#
# “경찰, 수사外 치안 기능도 가져…문민통제 필요 행정기관”
#
# 홍준표 “경찰 독립국 만들겠다는 건가...참 간 큰 조직 돼 간다”
#
# MY뉴스판 '기자 추천 카드' 오픈 안내
#
#
# 전체서비스
#
#
#
#
# 이용약관
# 개인정보처리방침
# 청소년 보호 책임자 : 이희만
# 서비스안내
#
# 각 언론사가 직접 콘텐츠를 편집합니다.

# %% [markdown]
# requests + bs

# %%
from bs4 import BeautifulSoup
import requests as rq

url = 'https://news.naver.com'
r = rq.get(url)
html = r.text
bs = BeautifulSoup(html, 'lxml')
text = bs.find('p').get_text()
text
# Out:
# '2018년 아이스쇼에서 첫 만남…비공개 결혼식 \'피겨퀸\' 김연아(32)가 오는 10월 결혼한다. 김연아의 매니지먼트사인 올댓스포츠는 25일 "김연아가 10월 하순 서울 모처에서 성악가 고우림(27)과 화촉을 밝힌다"'

# %% [markdown]
# #### 과제0725_2
# 기상청 육상 정보에서 강원도의 지역번호는 105이다. 강원도의 날씨 예보를 불필요한 공백을 제거한 후 출력하세요.

# %% [markdown]
# #### 과제0725_3
# "http://www.naver.com" 사이트에서 span 태그에 연결된 한글만을 불필요한 공백을 제거한 후 출력하세요.

# %% [markdown]
# #### 과제0725_4
# "http://www.naver.com" 사이트에서 span 태그에 연결된 문자 + 숫자를 불필요한 공백을 제거한 후 출력하세요.

# %% [markdown]
# #### 과제0725_5
# "http://www.naver.com" 사이트에서 a 태그에 id가 있는 경우에 대하여 연결된 문자 + 숫자를 불필요한 공백을 제거한 후 한줄에 출력하세요.

# %% [markdown]
# #### 과제0725_6
# url = 'https://news.naver.com/' 사이트 p태크에서 class가 cjs_ht인 데이터를 한글만을 불필요한 공백을 제거한 후 출력하세요.

# %%
from bs4 import BeautifulSoup
import urllib.request as rq

url = 'https://naver.com/'
html = rq.urlopen(url)
bs = BeautifulSoup(html,'lxml')

# print(bs.find('p'))
print(bs.find_all('p', limit=1),'\n')
print(bs.find_all('p', limit=2),'\n')
print(bs.find_all('p', limit=3))
# Out:
# [<p class="dsc">
# <i class="imsc ico_election"></i><span class="_alert_passage"></span>
# </p>]
#
# [<p class="dsc">
# <i class="imsc ico_election"></i><span class="_alert_passage"></span>
# </p>, <p class="dsc">ON/OFF 설정은<br/>해당기기(브라우저)에 저장됩니다.</p>]
#
# [<p class="dsc">
# <i class="imsc ico_election"></i><span class="_alert_passage"></span>
# </p>, <p class="dsc">ON/OFF 설정은<br/>해당기기(브라우저)에 저장됩니다.</p>, <p class="dsc"><em class="txt">동일한 시간대/연령/남녀별</em> 사용자 그룹의<br/>관심사에 맞춰 자동완성을 제공합니다.</p>]

# %%
from bs4 import BeautifulSoup
import requests as rq

url = 'https://news.daum.net/politics/'
html = rq.get(url)
html = html.text
bs = BeautifulSoup(html,'lxml')
title = bs.find('h2', id='mainContent').text
title
# Out:
# '정치'

# %%
from bs4 import BeautifulSoup
import requests as rq

url = 'https://news.daum.net/politics/'
html = rq.get(url)
html = html.text
bs = BeautifulSoup(html,'lxml')
title = bs.select_one('#gnbContent > div > ul > li.on > a > span').text
title
# Out:
# '정치'

# %%
# Q. 네이버 영화 랭킹 가져와서 첫번째 영화제목을 출력하세요.
from bs4 import BeautifulSoup
import requests as rq

url = 'https://movie.naver.com/movie/sdb/rank/rmovie.naver'
html = rq.get(url)
html = html.text

bs = BeautifulSoup(html,'lxml')
title = bs.select_one('#old_content > table > tbody > tr:nth-child(2) > td.title > div > a').text
title
# Out:
# '외계+인 1부'

# %%
# Q. 네이버 영화 랭킹 가져와서 첫번째 영화제목을 출력하세요.
# Q. 네이버 영화 랭킹 가져와서 첫번째 영화제목을 출력하세요
from bs4 import BeautifulSoup
import requests as rq

url = 'https://movie.naver.com/movie/sdb/rank/rmovie.naver'
html = rq.get(url)
# Q. 네이버 영화 랭킹 가져와서 첫번째 영화제목을 출력하세요
from bs4 import BeautifulSoup
import requests as rq

url = 'https://movie.naver.com/movie/sdb/rank/rmovie.naver'
html = rq.get(url)
html = html.text

bs = BeautifulSoup(html,'lxml')
title = bs.find_all('div',class_='tit3')
# for t in title:
#     print(t.text)
print(title[0].text)
# Out:
# 외계+인 1부

# %% [markdown]
# #### 과제0726_1
# 네이버 영화 랭킹 가져와서 조회순 전체 영화제목을 50개를 출력하세요(출력방식 1위 : 외계+인 1부)

# %%
html = """
<ul>
  <li><a href="hoge.html">hoge</li>
  <li><a href="https://example.com/fuga">fuga*</li>
  <li><a href="https://example.com/foo">foo*</li>
  <li><a href="http://example.com/aaa">aaa</li>
</ul>
"""
import re

bs = BeautifulSoup(html,'html.parser')
li = bs.find_all(href=re.compile('^https://'))
for e in li:
    print(e.attrs['href'])
# Out:
# https://example.com/fuga
# https://example.com/foo

# %% [markdown]
# ### CSS 선택자
# - 원하는 정보만 선별하여 수집하고 싶을 때 css선택자를 활용할 수 있음
# - (CSS 선택자 설명 추가)
# - F12 >> 수집하고 싶은 부분 클릭 >> 태그 선택 >> copy Selector
# - BeautifulSoup의 select_one, select 활용

# %%
import requests as rq
from bs4 import BeautifulSoup

url = 'https://news.daum.net/politics#1/'
r = rq.get(url)
html = r.text
bs = BeautifulSoup(html,'lxml')
lines = bs.select('body > div > main > section > div > div > ul > li > strong > a')
body = '\n'.join([line.text for line in lines])
print(body)
# Out:
# '경찰국 신설' 행안부 직제 개정안 국무회의 통과
# 2주째 잠행한 김정은..'전승절' 맞아 공식 석상 등장에 주목
# 尹의 업무보고 방식에 박지원 "세상에 그런 천재가 없어요" 힐난
# 전주혜 "초선들, 당 지지율 급락에 침묵? 신중함 필요"
# 정청래 "이재명 사법 리스크? 저쪽 프레임에 우리가 내부총질"
# 경찰국 신설 시행령 국무회의 의결..내달 2일 시행
# '지속 가능한 돌봄사회 제주' 주제 공동포럼 내달 2일 개최
# 완연한 감소세에도 여전한 '최대비상방역'..'변수'에 긴장하는 북한
# 대통령실 앞에 선 野.."모든 권한 집중해 경찰장악 저지"
# 이용호, 靑 개방공간 활용 위한 '총리 산하 TF' 구성 제안

# %%
import requests as rq
from bs4 import BeautifulSoup

url = 'https://news.daum.net/politics#1/'
r = rq.get(url)
html = r.text
bs = BeautifulSoup(html,'lxml')
line = bs.select_one('body > div.container-doc.cont-category > main > section > div.main-sub > div.box_g.box_news_major > ul > li:nth-child(1) > strong > a')
line.text
# Out:
# "2주 넘게 '두문불출' 김 여사..목요일 등장할까?"

# %%
# Q. "2주 넘게 '두문불출' 김 여사..목요일 등장할까?" 제목의 기사 내용을 출력하세요.(불필요한 공백 및 요소 제거)
url = 'https://news.v.daum.net/v/20220726105712920'
r = rq.get(url).text
bs = BeautifulSoup(r,'lxml')
lines2 = bs.select('#harmonyContainer > section')
body = ''.join(i.text for i in lines2)
print(re.sub('\n{2,}','\n',body))
# Out:
# ■ "마드리드 이후 김건희 여사가 안 보인다"
# 윤석열 대통령의 지지율 추이와 더불어 최근 언론이 자주 언급하는 기사는 "김건희 여사가 공개 행보를 중단했다"는 내용입니다.
# 북대서양조약기구, NATO 순방 동행을 마치고 난 뒤 두문불출하고 있다는 겁니다.
#  정치평론가들은 김 여사가 공개 행보에 나설 때마다 관심을 끌기는 했지만 팬클럽, 수행원, 제2부속실 설치, 명품 목걸이 논란 등으로 부정적인 여론이 대두되자 ‘리스크 관리’에 들어간 것으로 보고 있습니다.
# 장성철 공론센터 소장은 “김건희 여사가 최근 2주간 사라졌다”면서 “김 여사가 지지율에 중대한 영향을 끼친다는 정무적인 판단이 있었을 것”이라고 말했습니다. 배종찬 인사이트케이 소장 역시 윤 대통령의 지지율 하락 원인 중 하나로 김건희 여사를 꼽았습니다. 배 소장은 경제, 인사, 양극화, 김 여사, 도어스테핑의 앞글자를 딴 ‘경인양김도’가 지지율이 떨어진 이유라고 분석했습니다. 유튜브 채널 ‘시사저널 TV’에 출연한 진중권 전 교수는 “지금 김건희 여사는 잘하고 있는 것 아니냐?”는 사회자의 질문에 “그렇다. 조금 더 기다려야 될 것 같다”고 조언하기도 했습니다.
# ■ 공개행보 재개는? 목요일 진수식이 유력
# 그렇다면 김건희 여사는 언제쯤 다시 언론에 모습을 드러낼까요? 목요일인 28일이 될 가능성이 높습니다. 차세대 이지스함인 정조대왕 진수식이 열리는데, 여기에 참석하지 않을까 예상됩니다.
# 배에 이름을 붙이고 처음 물에 띄워 바다로 내보내는 의식인 진수식(進水式)에서는 진수도끼(보통 금토끼)로 밧줄을 끊거나 샴페인을 깨는 행사가 있습니다. 진수식의 하이라이트인데요, 관례적으로 여성이 해왔다고 합니다. 왜 여성이 하게 됐는지를 놓고 영국 빅토리아 여왕이 세레모니를 한 이후 관례로 굳어졌다는 설도 있고, 배(ship)를 여성 대명사인 she로 받는데서 유래했다 혹은 탯줄을 자르는 상징적인 의미가 있기 때문에 여성이 하게 됐다는 여러 가지 설들이 있습니다.
# 김건희 여사가 진수식에 등장할지는 목요일 확인할 수 있을 것 같습니다.
# 정승혜 기자 (luxmundi@mbc.co.kr)
# 기사 원문 - https://imnews.imbc.com/news/2022/politics/article/6392168_35666.html

# %%
from bs4 import BeautifulSoup
import requests as rq

url = 'https://news.v.daum.net/v/20220726105712920'
r = rq.get(url)
html = r.text
soup = BeautifulSoup(html, 'lxml')
lines = soup.select('#harmonyContainer > section > p')
article = [line.text for line in lines]
article = ' '.join(article)
article
# Out:
# '■ "마드리드 이후 김건희 여사가 안 보인다" 윤석열 대통령의 지지율 추이와 더불어 최근 언론이 자주 언급하는 기사는 "김건희 여사가 공개 행보를 중단했다"는 내용입니다.  북대서양조약기구, NATO 순방 동행을 마치고 난 뒤 두문불출하고 있다는 겁니다.  정치평론가들은 김 여사가 공개 행보에 나설 때마다 관심을 끌기는 했지만 팬클럽, 수행원, 제2부속실 설치, 명품 목걸이 논란 등으로 부정적인 여론이 대두되자 ‘리스크 관리’에 들어간 것으로 보고 있습니다.  장성철 공론센터 소장은 “김건희 여사가 최근 2주간 사라졌다”면서 “김 여사가 지지율에 중대한 영향을 끼친다는 정무적인 판단이 있었을 것”이라고 말했습니다. 배종찬 인사이트케이 소장 역시 윤 대통령의 지지율 하락 원인 중 하나로 김건희 여사를 꼽았습니다. 배 소장은 경제, 인사, 양극화, 김 여사, 도어스테핑의 앞글자를 딴 ‘경인양김도’가 지지율이 떨어진 이유라고 분석했습니다. 유튜브 채널 ‘시사저널 TV’에 출연한 진중권 전 교수는 “지금 김건희 여사는 잘하고 있는 것 아니냐?”는 사회자의 질문에 “그렇다. 조금 더 기다려야 될 것 같다”고 조언하기도 했습니다. ■ 공개행보 재개는? 목요일 진수식이 유력 그렇다면 김건희 여사는 언제쯤 다시 언론에 모습을 드러낼까요? 목요일인 28일이 될 가능성이 높습니다. 차세대 이지스함인 정조대왕 진수식이 열리는데, 여기에 참석하지 않을까 예상됩니다. 배에 이름을 붙이고 처음 물에 띄워 바다로 내보내는 의식인 진수식(進水式)에서는 진수도끼(보통 금토끼)로 밧줄을 끊거나 샴페인을 깨는 행사가 있습니다. 진수식의 하이라이트인데요, 관례적으로 여성이 해왔다고 합니다. 왜 여성이 하게 됐는지를 놓고 영국 빅토리아 여왕이 세레모니를 한 이후 관례로 굳어졌다는 설도 있고, 배(ship)를 여성 대명사인 she로 받는데서 유래했다 혹은 탯줄을 자르는 상징적인 의미가 있기 때문에 여성이 하게 됐다는 여러 가지 설들이 있습니다.  김건희 여사가 진수식에 등장할지는 목요일 확인할 수 있을 것 같습니다. 정승혜 기자 (luxmundi@mbc.co.kr) 기사 원문 - https://imnews.imbc.com/news/2022/politics/article/6392168_35666.html'

# %%
import requests as rq
from bs4 import BeautifulSoup

url = 'https://news.v.daum.net/v/20220726105712920'
r = rq.get(url)
html = r.text
bs = BeautifulSoup(html, 'lxml')
lines = bs.select_one('#harmonyContainer > section').text
line = re.sub('\n', ' ', lines)
line = re.sub('\s+', ' ', line)
print(line)
# Out:
#  ■ "마드리드 이후 김건희 여사가 안 보인다" 윤석열 대통령의 지지율 추이와 더불어 최근 언론이 자주 언급하는 기사는 "김건희 여사가 공개 행보를 중단했다"는 내용입니다. 북대서양조약기구, NATO 순방 동행을 마치고 난 뒤 두문불출하고 있다는 겁니다. 정치평론가들은 김 여사가 공개 행보에 나설 때마다 관심을 끌기는 했지만 팬클럽, 수행원, 제2부속실 설치, 명품 목걸이 논란 등으로 부정적인 여론이 대두되자 ‘리스크 관리’에 들어간 것으로 보고 있습니다. 장성철 공론센터 소장은 “김건희 여사가 최근 2주간 사라졌다”면서 “김 여사가 지지율에 중대한 영향을 끼친다는 정무적인 판단이 있었을 것”이라고 말했습니다. 배종찬 인사이트케이 소장 역시 윤 대통령의 지지율 하락 원인 중 하나로 김건희 여사를 꼽았습니다. 배 소장은 경제, 인사, 양극화, 김 여사, 도어스테핑의 앞글자를 딴 ‘경인양김도’가 지지율이 떨어진 이유라고 분석했습니다. 유튜브 채널 ‘시사저널 TV’에 출연한 진중권 전 교수는 “지금 김건희 여사는 잘하고 있는 것 아니냐?”는 사회자의 질문에 “그렇다. 조금 더 기다려야 될 것 같다”고 조언하기도 했습니다. ■ 공개행보 재개는? 목요일 진수식이 유력 그렇다면 김건희 여사는 언제쯤 다시 언론에 모습을 드러낼까요? 목요일인 28일이 될 가능성이 높습니다. 차세대 이지스함인 정조대왕 진수식이 열리는데, 여기에 참석하지 않을까 예상됩니다. 배에 이름을 붙이고 처음 물에 띄워 바다로 내보내는 의식인 진수식(進水式)에서는 진수도끼(보통 금토끼)로 밧줄을 끊거나 샴페인을 깨는 행사가 있습니다. 진수식의 하이라이트인데요, 관례적으로 여성이 해왔다고 합니다. 왜 여성이 하게 됐는지를 놓고 영국 빅토리아 여왕이 세레모니를 한 이후 관례로 굳어졌다는 설도 있고, 배(ship)를 여성 대명사인 she로 받는데서 유래했다 혹은 탯줄을 자르는 상징적인 의미가 있기 때문에 여성이 하게 됐다는 여러 가지 설들이 있습니다. 김건희 여사가 진수식에 등장할지는 목요일 확인할 수 있을 것 같습니다. 정승혜 기자 (luxmundi@mbc.co.kr) 기사 원문 - https://imnews.imbc.com/news/2022/politics/article/6392168_35666.html

# %% [markdown]
# #### 크롤링) 접속 차단되었을때 User-Agent지정(header)
# https://m.blog.naver.com/PostView.naver?isHttpsRedirect=true&blogId=kiddwannabe&logNo=221185808375

# %%
from bs4 import BeautifulSoup
import requests

headers = {"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.45 Safari/537.36"}

url = 'https://news.naver.com/main/main.naver?mode=LSD&mid=shm&sid1=102'
req = requests.get(url, headers=headers)
bs = BeautifulSoup(req.content, 'html.parser')
print(bs)
# Out:
# <!DOCTYPE HTML>
#
# <html lang="ko">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta contents="always" name="referrer"/>
# <meta content="600" http-equiv="refresh">
# <meta content="width=1106" name="viewport">
# <meta content="사회 : 네이버 뉴스" property="og:title"/>
# <meta content="website" property="og:type"/>
# <meta content="https://news.naver.com/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=102" property="og:url"/>
# <meta content="https://ssl.pstatic.net/static.news/image/news/ogtag/navernews_200x200_20160804.png" property="og:image">
# <meta content="교육, 언론, 의료, 인물, 사건사고 등 사회 분야 뉴스 제공" property="og:description"/>
# <meta content="네이버" property="og:article:author">
# <meta content="summary" name="twitter:card"/>
# <meta content="사회 : 네이버 뉴스" name="twitter:title"/>
# <meta content="네이버 뉴스" name="twitter:site"/>
# <meta content="네이버 뉴스" name="twitter:creator"/>
# <meta content="https://ssl.pstatic.net/static.news/image/news/ogtag/navernews_200x200_20160804.png" name="twitter:image"/>
# <meta content="교육, 언론, 의료, 인물, 사건사고 등 사회 분야 뉴스 제공" name="twitter:description"/>
# <title>사회 홈 : 네이버 뉴스	</title>
# <link href="https://ssl.pstatic.net/static.news/image/news/2014/favicon/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <link href="https://ssl.pstatic.net/static.news/pnews/resources/20220616_145844/css/common.css" rel="stylesheet" type="text/css"/>
# <link href="https://ssl.pstatic.net/static.news/pnews/resources/20220616_145844/css/news.css" rel="stylesheet" type="text/css"/>
# <script charset="euc-kr" src="https://ssl.pstatic.net/static.news/pnews/resources/20220616_145844/js/news.jindo.js" type="text/javascript"></script>
# <script charset="utf-8" src="https://ssl.pstatic.net/static.news/pnews/resources/20220616_145844/js/news.jquery.js" type="text/javascript"></script>
# <script type="text/javascript">
# var _MAIN_NEWS_MENU_ID='shm';
# var _MAIN_NEWS_SECTION_ID='103';
# var ccsrv='cc.naver.com';
# var g_ssc='news.sec';
# window.nsc = g_ssc;
# var gnb_service='news';
# var gnb_logout=encodeURIComponent(location.href);
# var gnb_template='gnb_utf8';
# var gnb_brightness = 3;
# var gnb_searchbox='on';
# var gnb_shortnick='on';
#
# var gnb_timestamp = "Tue Jul 26 11:28:10 KST 2022";
# </script>
# <script charset="euc-kr" src="https://ssl.pstatic.net/static.news/pnews/resources/20220616_145844/js/news.service.js" type="text/javascript"></script>
# <script>
#
#     var isUnderIE10 = navigator.appName === "Microsoft Internet Explorer";
#     if (!isUnderIE10) {
#         var gladSDK = document.createElement("script");
#         gladSDK.async = true;
#         gladSDK.src = "https://ssl.pstatic.net/tveta/libs/glad/prod/gfp-core.js";
#         document.head.appendChild(gladSDK);
#     }
#
#
#     window.gladsdk = window.gladsdk || { cmd: [] };
#
#     window.gladsdk.cmd.push(function () {
#         window.gladsdk.setGlobalConfig({enablePersistAd: true});
#         window.gladsdk.setHostMeta('theme', 'system');
#
#         window.gladsdk.defineAdSlot({
#             adUnitId: 'p_news_newsend',
#             adSlotElementId: 'glad_ad_newsend'
#         });
#         window.gladsdk.defineAdSlot({
#             adUnitId: 'p_news_newslist',
#             adSlotElementId: 'glad_ad_newslist'
#         });
#         window.gladsdk.defineAdSlot({
#             adUnitId: 'p_news_sidebox',
#             adSlotElementId: 'glad_ad_sidebox'
#         });
#     })
# </script>
# </meta></meta></meta></meta></head>
# <body>
# <div id="wrap">
# <!-- 광고적용 태그 추가 -->
# <div id="da_base"></div>
# <div id="da_stake"></div>
# <div class="header" id="header">
# <div id="u_skip">
# <a href="#lnb" tabindex="1"><span>메인 메뉴로 바로가기</span></a>
# <a href="#main_content" tabindex="2"><span>본문으로 바로가기</span></a>
# </div>
# <div class="snb_area">
# <div class="snb_inner">
# <div class="gnb_area">
# <div class="gnb_wrap">
# <div class="gnb_dark_type2" id="gnb"></div>
# </div>
# <div class="gnb_search is_hidden _search_content">
# </div>
# <div class="gnb_tool" id="gnb_search_tool">
# <a class="tool_button _search_content_toggle_btn nclicks(gnb.sch)" href="javascript:;"><span class="icon_search">검색</span></a>
# </div>
# </div>
# <div id="snb_wrap">
# <h1>
# <a class="h_logo nclicks(gnb.naver)" href="https://www.naver.com/"><span class="blind">NAVER</span></a>
# <a class="h_news nclicks(gnb.news)" href="/"><span class="blind">뉴스</span></a>
# </h1>
# <ul class="snb_related_service">
# <li><span class="snb_bdr"></span><a class="entertain nclicks(gnb.enter)" href="https://entertain.naver.com/home">TV연예</a></li>
# <li><span class="snb_bdr"></span><a class="sports nclicks(gnb.sports)" href="https://sports.news.naver.com">스포츠</a></li>
# <li><span class="snb_bdr"></span><a class="weather nclicks(gnb.weather)" href="https://weather.naver.com">날씨</a></li>
# <li><span class="snb_bdr"></span><a class="premium nclicks(gnb.premium)" href="https://contents.premium.naver.com">프리미엄</a></li>
# </ul>
# </div>
# </div>
# </div>
# <div class="lnb_area">
# <div class="lnb_inner">
# <div class="lnb_both">
# <div class="lnb_left">
# <div class="lnb_menu" id="lnb">
# <ul>
# <li><a class="nclicks(lnb.pcmedia)" href="/"><span class="tx">언론사별</span> </a></li>
# <li><a class="nclicks(lnb.pol)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=100"><span class="tx">정치</span> </a></li>
# <li><a class="nclicks(lnb.eco)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=101"><span class="tx">경제</span> </a></li>
# <li class="on"><a class="nclicks(lnb.soc)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=102"><span class="tx">사회</span> <span class="blind">선택됨</span></a></li>
# <li><a class="nclicks(lnb.lif)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=103"><span class="tx">생활/문화</span> </a></li>
# <li><a class="nclicks(lnb.sci)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=105"><span class="tx">IT/과학</span> </a></li>
# <li><a class="nclicks(lnb.wor)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=104"><span class="tx">세계</span> </a></li>
# <li><a class="nclicks(lnb.rankin)" href="/main/ranking/popularDay.naver?mid=etc&amp;sid1=111"><span class="tx">랭킹</span> </a></li>
# <li><a class="nclicks(lnb.paper)" href="/newspaper/home"><span class="tx">신문보기</span> </a></li>
# <li><a class="nclicks(lnb.opi)" href="/main/opinion/home.naver"><span class="tx">오피니언</span> </a></li>
# <li><a class="nclicks(lnb.tv)" href="/main/tv/index.naver?mid=tvh"><span class="tx">TV</span> </a></li>
# <li><a class="nclicks(lnb.fact)" href="/main/factcheck/main.naver"><span class="tx">팩트체크</span> </a></li>
# </ul>
# </div>
# </div>
# <div class="lnb_right">
# <div class="lnb_extra">
# <div class="lnb_extra_menu">
# <ul class="lnb_extra_menu_list">
# <li class="lnb_extra_menu_item"><a class="lnb_extra_menu_link nclicks(nct.right3)" href="https://news.naver.com/main/officeList.naver" title="전체 언론사">전체 언론사</a></li>
# <li class="lnb_extra_menu_item"><a class="lnb_extra_menu_link nclicks(STA.newsstand)" href="https://newsstand.naver.com/" target="_blank" title="뉴스스탠드">뉴스스탠드</a></li>
# <li class="lnb_extra_menu_item"><a class="lnb_extra_menu_link nclicks(nct.right4)" href="https://newslibrary.naver.com/search/searchByDate.nhn" target="_blank" title="라이브러리">라이브러리</a></li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="lnb">
# <span class="lnb_date"><strong>07</strong>.<strong>26</strong><span class="day">(화)</span></span>
# <ul class="lnb_side" tabindex="0">
# <li><a class="nclicks(slb.allmedia)" href="https://news.naver.com/main/officeList.naver" title="전체 언론사">전체 언론사</a></li>
# <li><a class="nclicks(slb.newsstand)" href="https://newsstand.naver.com/" target="_blank" title="뉴스스탠드">뉴스스탠드</a></li>
# <li><a class="nclicks(slb.library)" href="https://newslibrary.naver.com/search/searchByDate.nhn" target="_blank" title="라이브러리">라이브러리</a></li>
# </ul>
# </div>
# </div>
# <hr/>
# <table cellpadding="0" cellspacing="0" class="container">
# <caption class="blind">기사목록</caption>
# <colgroup>
# <col class="col_snb"/>
# <col class="col_content"/>
# <col class="col_aside"/>
# </colgroup>
# <tr>
# <td class="snb">
# <div class="snb" id="snb">
# <h2 class="h4"><a class="nclicks(lmn_soc.home)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=102">사회</a></h2>
# <ul class="nav">
# <li><a class="snb_s26 nclicks(lmn_soc.mnl,,1)" href="/main/list.naver?mode=LS2D&amp;mid=shm&amp;sid1=102&amp;sid2=249">사건사고 </a></li>
# <li><a class="snb_s27 nclicks(lmn_soc.mnl,,2)" href="/main/list.naver?mode=LS2D&amp;mid=shm&amp;sid1=102&amp;sid2=250">교육 </a></li>
# <li><a class="snb_s28 nclicks(lmn_soc.mnl,,3)" href="/main/list.naver?mode=LS2D&amp;mid=shm&amp;sid1=102&amp;sid2=251">노동 </a></li>
# <li><a class="snb_s29 nclicks(lmn_soc.mnl,,4)" href="/main/list.naver?mode=LS2D&amp;mid=shm&amp;sid1=102&amp;sid2=254">언론 </a></li>
# <li><a class="snb_s30 nclicks(lmn_soc.mnl,,5)" href="/main/list.naver?mode=LS2D&amp;mid=shm&amp;sid1=102&amp;sid2=252">환경 </a></li>
# <li><a class="snb_s31 nclicks(lmn_soc.mnl,,6)" href="/main/list.naver?mode=LS2D&amp;mid=shm&amp;sid1=102&amp;sid2=59b">인권/복지 </a></li>
# <li><a class="snb_s32 nclicks(lmn_soc.mnl,,7)" href="/main/list.naver?mode=LS2D&amp;mid=shm&amp;sid1=102&amp;sid2=255">식품/의료 </a></li>
# <li><a class="snb_s90 nclicks(lmn_soc.mnl,,8)" href="/main/list.naver?mode=LS2D&amp;mid=shm&amp;sid1=102&amp;sid2=256">지역 </a></li>
# <li><a class="snb_s104 nclicks(lmn_soc.mnl,,9)" href="/main/list.naver?mode=LS2D&amp;mid=shm&amp;sid1=102&amp;sid2=276">인물 </a></li>
# <li><a class="snb_s33 nclicks(lmn_soc.mnl,,10)" href="/main/list.naver?mode=LS2D&amp;mid=shm&amp;sid1=102&amp;sid2=257">사회 일반 </a></li>
# </ul>
# <div class="snb_banner">
# <a class="nclicks(lmn_soc.pmb,,1)" href="https://contents.premium.naver.com/"><img alt="네이버 프리미엄콘텐츠" height="74" src="https://imgnews.pstatic.net/image/upload/item/2021/05/28/233112515_DA%2540PC%25B4%25BA%25BD%25BA%25C1%25C2%25C3%25F8.png" width="71"/></a>
# </div>
# <div class="snb_banner">
# <a class="nclicks(lmn_soc.pmb,,1)" href="https://media.naver.com/channel/setting?back=main"><img alt="언론사 구독하기" height="74" src="https://imgnews.pstatic.net/image/upload/item/2021/01/14/142956425_144518244_%2525B8%2525F0%2525B9%2525D9%2525C0%2525CF%2525B8%2525DE%2525C0%2525CE.png" width="71"/></a>
# </div>
# </div>
# </td>
# <td class="content">
# <div class="content" id="main_content">
# <div class="list_body section_index">
# <div class="cluster">
# <div class="cluster_title">
# <span class="cluster_title_inner"><a class="cluster_title_icon_link _news_cluster_layer_btn" href="#biF7L"><i class="cluster_title_icon">안내</i>헤드라인 뉴스</a></span>
# <div class="cluster_title_layer _news_cluster_layer is_hidden">
# <div class="cluster_title_layer_text">
#                             헤드라인 뉴스와 각 기사묶음 타이틀은 <br/> 기사 내용을 기반으로 <strong>자동 추출</strong>됩니다.
#                         </div>
# <div class="cluster_title_layer_image"></div>
# <button class="cluster_title_layer_close _news_cluster_layer_close_btn" type="button">닫기</button>
# </div>
# </div>
# </div>
# <div class="_persist">
# <div class="cluster">
# <div class="cluster_group _cluster_content">
# <div class="cluster_head">
# <div class="cluster_head_inner">
# <a class="cluster_head_more nclicks(cls_nav.clstitle)" href="/main/clusterArticles.naver?id=c_202207250530_00000342&amp;mode=LSD&amp;mid=shm&amp;sid1=102&amp;oid=079&amp;aid=0003668229"><span class="cluster_head_more_icon_num">14</span><span class="blind">개의 관련뉴스 더보기</span></a>
# <div class="cluster_head_topic_wrap">
# <h2 class="cluster_head_topic">
# <a class="nclicks(cls_nav.clstitle)" href="/main/clusterArticles.naver?id=c_202207250530_00000342&amp;mode=LSD&amp;mid=shm&amp;sid1=102&amp;oid=079&amp;aid=0003668229">
# <span class="cluster_head_sub_topic">울산시 전국체전 대회운영사무실 준공 </span><span class="cluster_head_sub_topic">전국체육대회 막바지 준비상황 점검 </span>
# </a>
# </h2>
# </div>
# </div>
# </div>
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_nav.clsart)" href="https://n.news.naver.com/mnews/article/079/0003668229?sid=102">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/079/2022/07/26/3668229.jpg?type=nf132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_nav.clsart)" href="https://n.news.naver.com/mnews/article/079/0003668229?sid=102">울산시, 전국체전 대회운영사무실 준공</a>
# <div class="cluster_text_lede">울산시는 26일 종합운동장에서 2022년 전국체전과 전국장애인체전 대회운영사무실 준공식을 열었다고 밝혔다. 대회운영사무실은 기존 울산종합운동장 내 울산시 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news079,0003668229',params:{sid1:'102'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">노컷뉴스</div>
# </div>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news421,0006239608',params:{sid1:'102'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">뉴스1</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_nav.clsart)" href="https://n.news.naver.com/mnews/article/421/0
</span>
# </a>
# </h2>
# </div>
# </div>
# </div>
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_nav.clsart)" href="https://n.news.naver.com/mnews/article/088/0000768147?sid=102">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/088/2022/07/26/768147.jpg?type=nf132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_nav.clsart)" href="https://n.news.naver.com/mnews/article/088/0000768147?sid=102">지역농협 진흙탕 선거…금품 주고받은 출마자·대의원 68명 덜미</a>
# <div class="cluster_text_lede">대구 성서경찰서는 지역 농협의 비상임이사 선거 과정에서 금품을 주고받은 출마자와 대의원 등 68명을 농업협동조합법 위반 혐의로 검거했다고 26일 밝혔다. …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news088,0000768147',params:{sid1:'102'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">매일신문</div>
# </div>
# </div>
# </li>
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_nav.clsart)" href="https://n.news.naver.com/mnews/article/421/0006238103?sid=102">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/421/2022/07/25/6238103.jpg?type=nf132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_nav.clsart)" href="https://n.news.naver.com/mnews/article/421/0006238103?sid=102">아직도 이런일이...돈으로 표 사려한 농협 비상임이사 후보들</a>
# <div class="cluster_text_lede">제주도내 농협 비상임이사 선거 과정에서 유권자에게 금품을 건넨 후보가 징역형을 받았다. 제주지방법원 형사3단독(강란주 판사)은 농업협동조합법 위반으로 기 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news421,0006238103',params:{sid1:'102'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">뉴스1</div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# </div>
# <div class="cluster_group _cluster_content">
# <div class="cluster_head">
# <div class="cluster_head_inner">
# <a class="cluster_head_more nclicks(cls_nav.clstitle)" href="/main/clusterArticles.naver?id=c_202207251130_00000005&amp;mode=LSD&amp;mid=shm&amp;sid1=102&amp;oid=011&amp;aid=0004080301"><span class="cluster_head_more_icon_num">25</span><span class="blind">개의 관련뉴스 더보기</span></a>
# <div class="cluster_head_topic_wrap">
# <h2 class="cluster_head_topic">
# <a class="nclicks(cls_nav.clstitle)" href="/main/clusterArticles.naver?id=c_202207251130_00000005&amp;mode=LSD&amp;mid=shm&amp;sid1=102&amp;oid=011&amp;aid=0004080301">
# <span class="cluster_head_sub_topic">상반기 정유 수출액 36.7조원 </span><span class="cluster_head_sub_topic">"전국 시도 중 최고" </span>
# </a>
# </h2>
# </div>
# </div>
# </div>
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_nav.clsart)" href="https://n.news.naver.com/mnews/article/011/0004080301?sid=102">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/011/2022/07/26/4080301.jpg?type=nf132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_nav.clsart)" href="https://n.news.naver.com/mnews/article/011/0004080301?sid=102">상반기 정유업계 수출액 역대 최대…국가 주요수출품목 2위로</a>
# <div class="cluster_text_lede">올해 상반기 정유업계 수출액이 반기 사상 역대 최대치를 기록한 것으로 나타났다. 26일 대한석유협회에 따르면 SK에너지·GS칼텍스·에쓰오일·현대오일뱅크  …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news011,0004080301',params:{sid1:'102'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">서울경제</div>
# </div>
# </div>
# </li>
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_nav.clsart)" href="https://n.news.naver.com/mnews/article/014/0004873100?sid=102">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/014/2022/07/26/4873100.jpg?type=nf132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_nav.clsart)" href="https://n.news.naver.com/mnews/article/014/0004873100?sid=102">올 상반기 국내 정유업계 석유제품 수출액 역대 최대치</a>
# <div class="cluster_text_lede">올해 상반기 국내 정유업계의 석유제품 수출액이 역대 최대치를 기록한 것으로 나타났다. 26일 대한석유협회에 따르면 SK에너지, GS칼텍스, 에쓰오일, 현 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news014,0004873100',params:{sid1:'102'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">파이낸셜뉴스</div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# </div>
# <div class="cluster_group _cluster_content">
# <div class="cluster_head">
# <div class="cluster_head_inner">
# <a class="cluster_head_more nclicks(cls_nav.clstitle)" href="/main/clusterArticles.naver?id=c_202207260650_00000033&amp;mode=LSD&amp;mid=shm&amp;sid1=102&amp;oid=052&amp;aid=0001768649"><span class="cluster_head_more_icon_num">19</span><span class="blind">개의 관련뉴스 더보기</span></a>
# <div class="cluster_head_topic_wrap">
# <h2 class="cluster_head_topic">
# <a class="nclicks(cls_nav.clstitle)" href="/main/clusterArticles.naver?id=c_202207260650_00000033&amp;mode=LSD&amp;mid=shm&amp;sid1=102&amp;oid=052&amp;aid=0001768649">
# <span class="cluster_head_sub_topic">만평 올린 전장연 </span><span class="cluster_head_sub_topic">우영우엔 공감 우리에겐 욕설 </span>
# </a>
# </h2>
# </div>
# </div>
# </div>
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_nav.clsart)" href="https://n.news.naver.com/mnews/article/052/0001768649?sid=102">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/052/2022/07/26/1768649.jpg?type=nf132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_nav.clsart)" href="https://n.news.naver.com/mnews/article/052/0001768649?sid=102">"우영우는 공감, 출근길 시위는 욕설"...전장연, SNS 만평 올려</a>
# <div class="cluster_text_lede">장애인의 이동권 보장을 요구하며 출근길 지하철 시위를 이어온 전국장애인차별철폐연대가 자폐 스펙트럼 장애를 다룬 드라마 '이상한 변호사 우영우'의 인기를  …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news052,0001768649',params:{sid1:'102'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">YTN</div>
# </div>
# </div>
# </li>
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_nav.clsart)" href="https://n.news.naver.com/mnews/article/016/0002020395?sid=102">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/016/2022/07/26/2020395.jpg?type=nf132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_nav.clsart)" href="https://n.news.naver.com/mnews/article/016/0002020395?sid=102">“우영우는 공감, 지하철 장애인은 조롱·욕설” 만평 올린 전장연</a>
# <div class="cluster_text_lede">'장애인 이동권 보장' 등을 내걸고 출근길 지하철 시위에 나선 전국장애인차별철폐연대(전장연)가 자폐 스펙트럼 장애인을 다룬 드라마 '이상한 변호사 우영우 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news016,0002020395',params:{sid1:'102'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">헤럴드경제</div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# </div>
# <div class="cluster_group _cluster_content">
# <div class="cluster_head">
# <div class="cluster_head_inner">
# <a class="cluster_head_more nclicks(cls_nav.clstitle)" href="/main/clusterArticles.naver?id=c_202207260910_00000036&amp;mode=LSD&amp;mid=shm&amp;sid1=102&amp;oid=018&amp;aid=0005277085"><span class="cluster_head_more_icon_num">28</span><span class="blind">개의 관련뉴스 더보기</span></a>
# <div class="cluster_head_topic_wrap">
# <h2 class="cluster_head_topic">
# <a class="nclicks(cls_nav.clstitle)" href="/main/clusterArticles.naver?id=c_202207260910_00000036&amp;mode=LSD&amp;mid=shm&amp;sid1=102&amp;oid=018&amp;aid=0005277085">
# <span class="cluster_head_sub_topic">14만 전체 경찰회의로 확대 </span><span class="cluster_head_sub_topic">경찰국 반발 격화 </span>
# </a>
# </h2>
# </div>
# </div>
# </div>
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_nav.clsart)" href="https://n.news.naver.com/mnews/article/018/0005277085?sid=102">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/018/2022/07/26/5277085.jpg?type=nf132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_nav.clsart)" href="https://n.news.naver.com/mnews/article
jpg?type=nf132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_nav.clsart)" href="https://n.news.naver.com/mnews/article/421/0006239740?sid=102">택시비 1만5000원 낸다고 해놓고 무임승차 60대 '벌금 100만원'</a>
# <div class="cluster_text_lede">결제수단이 없는 상태에서 택시를 타고 이동한 혐의로 기소된 60대 남성이 법원으로부터 벌금형을 선고받았다. 춘천지법 원주지원(형사 1단독 공민아 판사)은 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news421,0006239740',params:{sid1:'102'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">뉴스1</div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# </div>
# <div class="cluster_group _cluster_content" style="display: none">
# <div class="cluster_head">
# <div class="cluster_head_inner">
# <a class="cluster_head_more nclicks(cls_nav.clstitle)" href="/main/clusterArticles.naver?id=c_202207251140_00000303&amp;mode=LSD&amp;mid=shm&amp;sid1=102&amp;oid=031&amp;aid=0000687648"><span class="cluster_head_more_icon_num">13</span><span class="blind">개의 관련뉴스 더보기</span></a>
# <div class="cluster_head_topic_wrap">
# <h2 class="cluster_head_topic">
# <a class="nclicks(cls_nav.clstitle)" href="/main/clusterArticles.naver?id=c_202207251140_00000303&amp;mode=LSD&amp;mid=shm&amp;sid1=102&amp;oid=031&amp;aid=0000687648">
# <span class="cluster_head_sub_topic">에어컨 위에 또 에어컨? </span><span class="cluster_head_sub_topic">"300만원 넘게 줬는데…" </span>
# </a>
# </h2>
# </div>
# </div>
# </div>
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_nav.clsart)" href="https://n.news.naver.com/mnews/article/031/0000687648?sid=102">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/031/2022/07/25/687648.jpg?type=nf132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_nav.clsart)" href="https://n.news.naver.com/mnews/article/031/0000687648?sid=102">"부모님 댁에 2in1 에어컨 설치했더니 이렇게…" 시끌</a>
# <div class="cluster_text_lede">스탠드형과 벽걸이형 에어컨을 한 구성으로 묶어파는 2in1 에어컨이 설치된 사진 한 장이 온라인을 뜨겁게 달구고 있다. 최근 한 온라인 커뮤니티에 "부모 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news031,0000687648',params:{sid1:'102'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">아이뉴스24</div>
# </div>
# </div>
# </li>
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_nav.clsart)" href="https://n.news.naver.com/mnews/article/003/0011326136?sid=102">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/003/2022/07/26/11326136.jpg?type=nf132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_nav.clsart)" href="https://n.news.naver.com/mnews/article/003/0011326136?sid=102">"우리 부모님 집에도 에어컨 위에 또 에어컨...화가 난다"</a>
# <div class="cluster_text_lede">기사내용 요약 "리모컨 하나로 동시 작동한다는 설명도 안해주고 갔다" "70대 노인이 사는 집이라 대충하고 간 건지 화가 난다" [서울=뉴시스]하나의 실 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news003,0011326136',params:{sid1:'102'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">뉴시스</div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# </div>
# <div class="cluster_group _cluster_content" style="display: none">
# <div class="cluster_head">
# <div class="cluster_head_inner">
# <a class="cluster_head_more nclicks(cls_nav.clstitle)" href="/main/clusterArticles.naver?id=c_202207251210_00000010&amp;mode=LSD&amp;mid=shm&amp;sid1=102&amp;oid=421&amp;aid=0006238245"><span class="cluster_head_more_icon_num">25</span><span class="blind">개의 관련뉴스 더보기</span></a>
# <div class="cluster_head_topic_wrap">
# <h2 class="cluster_head_topic">
# <a class="nclicks(cls_nav.clstitle)" href="/main/clusterArticles.naver?id=c_202207251210_00000010&amp;mode=LSD&amp;mid=shm&amp;sid1=102&amp;oid=421&amp;aid=0006238245">
# <span class="cluster_head_sub_topic">산재보험 가입자 2000만명 눈앞 </span><span class="cluster_head_sub_topic">특고 적용 확대에 </span>
# </a>
# </h2>
# </div>
# </div>
# </div>
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_nav.clsart)" href="https://n.news.naver.com/mnews/article/421/0006238245?sid=102">
# ...
# <li>
# <a class="ranking_thumb nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/659/0000004363?ntype=RANKING&amp;sid=001">
# <img alt="" height="60" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';" src="https://mimgnews.pstatic.net/image/origin/659/2022/07/24/4363.jpg?type=nf88_60" width="88"/>
# <strong class="r_ico r_vod_small">동영상기사</strong>
# </a>
# <div class="list_text_wrap">
# <div class="list_text">
# <div class="list_text_inner">
# <a class="list_tit nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/659/0000004363?ntype=RANKING&amp;sid=001">수도권 쏠림 "불 보듯".. 반발 확산</a>
# <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=659"><span class="list_press_thumb"><img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/659/2022/01/19/logo_659_56_20220119141438.png" width="16"/></span>전주MBC</a>
# </div>
# </div>
# </div>
# </li>
# <li>
# <a class="ranking_thumb nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/655/0000003431?ntype=RANKING&amp;sid=001">
# <img alt="" height="60" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';" src="https://mimgnews.pstatic.net/image/origin/655/2022/07/26/3431.jpg?type=nf88_60" width="88"/>
# </a>
# <div class="list_text_wrap">
# <div class="list_text">
# <div class="list_text_inner">
# <a class="list_tit nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/655/0000003431?ntype=RANKING&amp;sid=001">[지수로 보는 날씨정보] 여름철 침구 관리 이렇게</a>
# <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=655"><span class="list_press_thumb"><img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/655/2022/01/20/logo_655_56_20220120164501.png" width="16"/></span>CJB청주방송</a>
# </div>
# </div>
# </div>
# </li>
# <li>
# <a class="ranking_thumb nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/660/0000013290?ntype=RANKING&amp;sid=001">
# <img alt="" height="60" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';" src="https://mimgnews.pstatic.net/image/origin/660/2022/07/26/13290.jpg?type=nf88_60" width="88"/>
# </a>
# <div class="list_text_wrap">
# <div class="list_text">
# <div class="list_text_inner">
# <a class="list_tit nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/660/0000013290?ntype=RANKING&amp;sid=001">박지원, '12·12' 빗댄 이상민에 "경찰이 총 쏘고 한 …</a>
# <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=660"><span class="list_press_thumb"><img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/660/2022/01/19/logo_660_56_20220119141745.png" width="16"/></span>kbc광주방송</a>
# </div>
# </div>
# </div>
# </li>
# <li>
# <a class="ranking_thumb nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/662/0000004014?ntype=RANKING&amp;sid=001">
# <img alt="" height="60" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';" src="https://mimgnews.pstatic.net/image/origin/662/2022/07/25/4014.jpg?type=nf88_60" width="88"/>
# </a>
# <div class="list_text_wrap">
# <div class="list_text">
# <div class="list_text_inner">
# <a class="list_tit nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/662/0000004014?ntype=RANKING&amp;sid=001">목의 이물감·호흡곤란 지속되면…‘○○○암’ 의심</a>
# <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=662"><span class="list_press_thumb"><img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/662/2022/04/28/logo_662_56_20220428101949.png" width="16"/></span>농민신문</a>
# </div>
# </div>
# </div>
# </li>
# <li>
# <a class="ranking_thumb nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/145/0000016694?ntype=RANKING&amp;sid=001">
# <img alt="" height="60" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';" src="https://mimgnews.pstatic.net/image/origin/145/2022/07/25/16694.jpg?type=nf88_60" width="88"/>
# </a>
# <div class="list_text_wrap">
# <div class="list_text">
# <div class="list_text_inner">
# <a class="list_tit nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/145/0000016694?ntype=RANKING&amp;sid=001">[임성용의 보약밥상] 염증 완화와 암 증식 억제에 좋은 ‘ …</a>
# <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=145"><span class="list_press_thumb"><img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/145/2020/12/09/logo_145_56_20201209180915.png" width="16"/></span>레이디경향</a>
# </div>
# </div>
# </div>
# </li>
# </ul>
# <button class="refresh_button nclicks('rig.renws2new') _refreshButton" type="button">더보기</button>
# </div>
# <script type="text/javascript">
#     var OfficeTopRankingManager = jindo.$Class({
#         $static: {
#             RANKING_INFO_BUTTON_SELECTOR: '._rankingInfoButton',
#             RANKING_INFO_LAYER_SELECTOR : '._rankingInfoLayer',
#             RANKING_INFO_BUTTON_CLOSE_SELECTOR : '._rankingInfoCloseButton',
#             REFRESH_BUTTON_SELECTOR : '._refreshButton',
#             RANKING_LIST_SELECTOR : '._rankingList'
#         },
#
#         $init: function(base) {
#             this._welBase = jindo.$Element(base);
#             this._rankingInfoLayer = jindo.$Element(this._welBase.query(this.constructor.RANKING_INFO_LAYER_SELECTOR));
#             this._rankingListArray = jindo.$ElementList(this._welBase.queryAll(this.constructor.RANKING_LIST_SELECTOR));
#
#             this._initEvent();
#         },
#
#         _initEvent: function() {
#             this._welBase.delegate('click', this.constructor.RANKING_INFO_BUTTON_SELECTOR, jindo.$Fn(this._showRankingInfoLayer, this).bind());
#             this._welBase.delegate('click', this.constructor.RANKING_INFO_BUTTON_CLOSE_SELECTOR, jindo.$Fn(this._closeRankingInfoLayer, this).bind());
#             this._welBase.delegate('click', this.constructor.REFRESH_BUTTON_SELECTOR, jindo.$Fn(this._refreshRankingList, this).bind());
#         },
#
#         _showRankingInfoLayer: function(event) {
#             event.stopDefault();
#
#             this._rankingInfoLayer.toggle();
#         },
#
#         _closeRankingInfoLayer: function(event) {
#             event.stopDefault();
#
#             this._rankingInfoLayer.hide();
#         },
#
#         _refreshRankingList: function(event) {
#             event.stopDefault();
#
#             for (var i=0 ; i<this._rankingListArray.length() ; i++) {
#                 var rankingList = this._rankingListArray.get(i);
#
#                 if (rankingList.visible() === true) {
#                     var nextIndex = i + 1;
#
#                     if (nextIndex === this._rankingListArray.length()) {
#                         nextIndex = 0;
#                     }
#
#                     var nextRankingList = this._rankingListArray.get(nextIndex);
#
#                     rankingList.hide();
#                     nextRankingList.show();
#
#                     break;
#                 }
#             }
#         }
#     });
#
#     window.addEventListener("load", function() {
#         var officeTopRanking = jindo.$$.getSingle("._officeTopRanking1087475");
#         if (officeTopRanking) {
#             new OfficeTopRankingManager(officeTopRanking);
#         }
#     });
# </script>
# <div class="side_ad" id="glad_ad_sidebox"></div>
# <div class="section" id="right_dailyList" style="margin-bottom:20px; white-space:nowrap;">
# <h4>분야별 주요뉴스</h4>
# <div class="classfy sd" style="display:block">
# <ul class="list_txt">
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/025/0003212295?sid=100" title="[속보]'행안부 경찰국 신설안' 국무회의 의결…8월2일부터 시행">[속보]'행안부 경찰국 신설안' 국무회의 의결…8월2일부터 시행</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/001/0013333850?sid=100" title='尹대통령 "치안 관서장 집단행동 깊은 우려…중대 국가기강문란"(종합)'>尹대통령 "치안 관서장 집단행동 깊은 우려…중대 국가기강문란"(종합)</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/081/0003290038?sid=100" title="安, ‘김경수 사면’ 공개 반대…“드루킹 조작으로 부정적 이미지”">安, ‘김경수 사면’ 공개 반대…“드루킹 조작으로 부정적 이미지”</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/003/0011325538?sid=104" title="'보건 위기'된 원숭이두창, 감염 위험 얼마나 높을까?">'보건 위기'된 원숭이두창, 감염 위험 얼마나 높을까?</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/028/0002600003?sid=104" title="미얀마 군부, 민주화 활동가 4명 전격 처형…국제사회 ‘충격’">미얀마 군부, 민주화 활동가 4명 전격 처형…국제사회 ‘충격’</a> </li>
# </ul>
# <ul class="list_txt">
# <ul class="list_txt">
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/366/0000829968?sid=101" title="2분기 성장률 서프라이즈, 펜트업 효과…한은 “하반기 수출·소비 동반 부진 가능성”">2분기 성장률 서프라이즈, 펜트업 효과…한은 “하반기 수출·소비 동반 부진 가능성”</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/648/0000009363?sid=101" title="용산정비창, '1만 가구' 대신 국제업무지구로…'용적률 1500% 이상'">용산정비창, '1만 가구' 대신 국제업무지구로…'용적률 1500% 이상'</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/366/0000829962?sid=101" title="지역 소상공인 찾아간 이복현 금감원장 “금융권 지원 강화”">지역 소상공인 찾아간 이복현 금감원장 “금융권 지원 강화”</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/003/0011325928?sid=105" title="올 상반기 5G 통신분쟁 신청 급증…전년 대비 3배 수준">올 상반기 5G 통신분쟁 신청 급증…전년 대비 3배 수준</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/092/0002263516?sid=105" title='네이버 노조 "5개 계열사 쟁의행위 본격화"'>네이버 노조 "5개 계열사 쟁의행위 본격화"</a> </li>
# </ul>
# <ul class="list_txt">
# <ul class="list_txt">
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/421/0006240039?sid=102" title="석달만에 10만명 '코앞'…신규 확진 9만9327명(종합)">석달만에 10만명 '코앞'…신규 확진 9만9327명(종합)</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/014/0004873062?sid=102" title="이상민 &quot;무기, 쿠데타&quot;에 &quot;총, 무기 1도 관계 없어&quot;, 경감이 불붙인 '전체 경찰회의'">이상민 "무기, 쿠데타"에 "총, 무기 1도 관계 없어", 경감이 불붙인 '전체 경찰회의'</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/009/0004996333?sid=102" title="광주 고교 '답안지 유출' 사실이었다…학생 2명 교사 컴퓨터에 악성코드 심어">광주 고교 '답안지 유출' 사실이었다…학생 2명 교사 컴퓨터에 악성코드 심어</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/003/0011325443?sid=103" title="'중복'에 폭염 이어져...일부 지역은 열대야도">'중복'에 폭염 이어져...일부 지역은 열대야도</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/052/0001768676?sid=103" title="[날씨] '중복' 전국 폭염특보, 서울 33℃...오후 소나기">[날씨] '중복' 전국 폭염특보, 서울 33℃...오후 소나기</a> </li>
# </ul>
# </ul>
# </ul>
# </div>
# </div>
# <div class="section">
# <div class="banner">
# <a class="nclicks(rig.banner)" href="https://media.naver.com/channel/settings"> <img alt="네이버 메인에서 바로 보는 언론사 편집뉴스 지금 바로 구독해보세요!" src="https://imgnews.pstatic.net/image/upload/item/2018/11/27/175025584_PC_%25BF%25EC%25C3%25F8%25B9%25E8%25B3%25CA_%25B1%25B8%25B5%25B6%25C8%25B0%25BC%25BA%25C8%25AD.png" width="300"> </img></a>
# </div>
# </div>
# <div class="section">
# <div class="banner">
# <a class="nclicks(rig.banner)" href="https://news.naver.com/main/ombudsman/guidecenter.naver?mid=omb" target="_blank"> <img alt="뉴스 기사와 댓글로 인한 문제 발생 시 24시간 센터로 접수해주세요" src="https://imgnews.pstatic.net/image/upload/item/2018/08/29/183254054_%25BD%25C5%25B0%25ED%25B9%25E8%25B3%25CA.png" width="300"> </img></a>
# </div>
# </div>
# <div class="section">
# <h4> <a class="nclicks(rig.text)" href="https://news.naver.com/main/ombudsman/index.naver"> 서비스 안내 </a> </h4>
# <ul class="list_txt">
# <li> <a class="nclicks(rig.text)" href="https://news.naver.com/main/ombudsman/errorArticleList.naver?mid=omb"> 고침 기사 모음 </a> </li>
# <li> <a class="nclicks(rig.text)" href="https://news.naver.com/main/ombudsman/revisionArticleList.naver?mid=omb"> 정정·반론·추후 보도 기사 모음 </a> </li>
# <li> <a class="nclicks(rig.text)" href="https://news.naver.com/main/hotissue/sectionList.naver?mid=hot&amp;sid1=100&amp;cid=909906&amp;decorator=ombudsman&amp;confirm=true"> 불공정 선거 보도 기사 모음 </a> </li>
# </ul>
# <a class="more_link nclicks(rig.text)" href="https://news.naver.com/main/ombudsman/index.naver"><span class="blind">서비스 안내</span>더보기</a>
# </div>
# <script>
#     window.gladsdk.cmd.push(function () {
#         var adSlot = window.gladsdk.findAdSlot("glad_ad_sidebox");
#
#         adSlot.setCustomParam("calp", 'shome');
#         window.gladsdk.displayAd(adSlot);
#     });
# </script>
# </div>
# </td>
# </tr>
# </table>
# </div>
# <hr/>
# <div class="index">
# <div class="index_inner">
# <div class="floating_btn">
# <div class="floating_inner">
# <a class="floating_btn_back" href="javascript:history.back();"><span class="blind">이젠 페이지</span></a>
# <a class="floating_btn_top" href="#" onclick="window.scrollTo(0,0);oWebAccessibilityUtil.moveFocus(document.getElementById('da_base'));return false;"><span class="blind">맨위로</span></a>
# </div>
# </div>
# <div class="index_tab" id="index.press_category">
# <a class="spr stit nclicks(fot.press)" href="#" id="index.press.btn">언론사 목록<span class="_stit_tab_arrow stit_arrow"><span class="blind">열기</span></span><span class="loading" style="display:none;">로딩 중</span></a>
# <div class="index_content is_hidden" id="index.press.area"></div>
# <a class="spr stit2 nclicks(fot.section)" href="#" id="index.category.btn">분야별 목록<span class="_stit_tab_arrow stit_arrow"><span class="blind">열기</span></span><span class="loading" style="display:none;">로딩 중</span></a>
# <div class="index_content02 is_hidden" id="index.category.area"></div>
# </div>
# </div>
# </div>
# <hr/>
# <div id="footer">
# <ul>
# <li class="first"><a class="nclicks(fot.agreement)" href="http://www.naver.com/rules/service.html">이용약관</a></li>
# <li><a class="nclicks(fot.guide)" href="/main/ombudsman/index.naver">서비스 안내</a></li>
# <li><a class="nclicks(fot.editor)" href="/main/ombudsman/edit.naver?mid=omb">기사배열 원칙 책임자 : 유봉석</a></li>
# <li>청소년 보호 책임자 : 이희만</li>
# <li><strong><a class="nclicks(fot.privacy)" href="http://www.naver.com/rules/privacy.html">개인정보처리방침</a></strong></li>
# <li><a class="nclicks(fot.disclaimer)" href="http://www.naver.com/rules/disclaimer.html">책임의 한계와 법적고지</a></li>
# <li><a class="nclicks(fot.help)" href="#" onclick="news.external.OPS.helpNews(); return false;" title="새창">뉴스 고객센터</a></li>
# </ul>
# <p class="copyright">본 콘텐츠의 저작권은 제공처 또는 네이버에 있으며 이를 무단 이용하는 경우 저작권법 등에 따라 법적책임을 질 수 있습니다.</p>
# <address class="address_nhn">
# <a class="logo nclicks(fot.naver)" href="https://www.navercorp.com/" target="_blank"><span class="blind">NAVER</span></a>
# <em>Copyright ©</em>
# <a class="nclicks(fot.navercorp)" href="https://www.navercorp.com/" target="_blank">NAVER Corp.</a>
# <span>All Rights Reserved.</span>
# </address>
# <!-- -->
# </div>
# <script type="text/javascript">
#
#
#
#
#
#
#
# var index_tab = new news.index.TabController('index.press_category');
# index_tab.add(new news.index.Tab('index.press.btn','stit','index.press.area','/main/ajax/bottomIndex/press.naver'));
# index_tab.add(new news.index.Tab('index.category.btn','stit2','index.category.area','/main/ajax/bottomIndex/category.naver'));
# jindo.$Fn(index_tab.toggle, index_tab).attach(index_tab.tabs.keys(), 'click');
#
#
# (function() {
# 	news.right.RightSideFloatingManager.init();
# })();
#
#
#
#     (function() {
#         news.right.TopDownFloatingManager.init();
#     })();
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ;(function(){
#     var eventType = "onpageshow" in window ? "pageshow" : "load";
#     jindo.$Fn(function(){
#
#
# 	lcs_do();
#
#     }).attach(window, eventType);
# })();
#
#
#
#
#
#
#
#
# news.startup();
#
#
# jindo.$Fn(function(){
#     var welSkip = jindo.$Element("u_skip");
#     if (welSkip === null) {
#         return;
#     }
#     welSkip.delegate("click", "a", function(weEvent){
#         weEvent.stopDefault();
#         var elTarget = jindo.$(weEvent.element.href.split("#")[1]);
#         oWebAccessibilityUtil.moveFocus(elTarget);
#     });
# }).attach(window, "load");
#
#
# document.documentElement.setAttribute('data-useragent',navigator.userAgent);
# </script>
# </body>
# </html>

# %%
target = bs.select_one('#main_content > div > div._persist > div:nth-child(1) > div:nth-child(1) > div.cluster_body > ul > li:nth-child(1) > div.cluster_text > a')
print(target.text,'\n')
print(target,'\n')
print(target['class'],'\n')
print(target['href'])
# Out:
# 울산시, 전국체전 대회운영사무실 준공
#
# <a class="cluster_text_headline nclicks(cls_nav.clsart)" href="https://n.news.naver.com/mnews/article/079/0003668229?sid=102">울산시, 전국체전 대회운영사무실 준공</a>
#
# ['cluster_text_headline', 'nclicks(cls_nav.clsart)']
#
# https://n.news.naver.com/mnews/article/079/0003668229?sid=102

# %%
target = bs.select('#main_content > div > div > div > div > div > ul > li > div > a')
for element in target:
    print(element.text)
    print(element['href'])
# Out:
# 울산시, 전국체전 대회운영사무실 준공
# https://n.news.naver.com/mnews/article/079/0003668229?sid=102
# 울산시, 전국(장애인)체전 대회운영사무실 준공
# https://n.news.naver.com/mnews/article/421/0006239608?sid=102
# 이상민 장관 “전국 경찰서장 회의, 12·12 쿠데타만큼 부적절”
# https://n.news.naver.com/mnews/article/023/0003705906?sid=102
# 전국 7개 국제공항, 국제선 하늘길 활짝
# https://n.news.naver.com/mnews/article/022/0003718953?sid=102
# "하늘길 모두 열렸다"…7개 지방 국제공항 국제선 전면 재개
# https://n.news.naver.com/mnews/article/001/0013333975?sid=102
# 택시비 1만5000원 안주려다 67배 물어낸 50대, 무슨일이
# https://n.news.naver.com/mnews/article/009/0004996250?sid=102
# 택시비 1만5000원 낸다고 해놓고 무임승차 60대 '벌금 100만원'
# https://n.news.naver.com/mnews/article/421/0006239740?sid=102
# "부모님 댁에 2in1 에어컨 설치했더니 이렇게…" 시끌
# https://n.news.naver.com/mnews/article/031/0000687648?sid=102
# "우리 부모님 집에도 에어컨 위에 또 에어컨...화가 난다"
# https://n.news.naver.com/mnews/article/003/0011326136?sid=102
# 산재보험 가입자 수 2000만명 돌파 임박…6월말 기준 1987만명
# https://n.news.naver.com/mnews/article/421/0006238245?sid=102
# 고용부, 외국인 '고용허가서' 받으려면 산재 가입부터
# https://n.news.naver.com/mnews/article/016/0002020475?sid=102
# 하루 확진자 3개월여만에 10만명 육박...켄타우로스 지역 감염 첫 확인
# https://n.news.naver.com/mnews/article/016/0002020433?sid=102
# 신규확진자 이미 10만명 육박…'더블링' 둔화에도 증가세 지속
# https://n.news.naver.com/mnews/article/001/0013333560?sid=102
# 신경주역 부근 신호 장애로 열차 지연… 승객 불편 이어져
# https://n.news.naver.com/mnews/article/022/0003718960?sid=102
# 신호 장애로 KTX·SRT 열차 운행 지연...복구 완료
# https://n.news.naver.com/mnews/article/052/0001768689?sid=102
# 광주 모 교교 기말고사 유출 의혹…'답안지 추정 쪽지' 버린 학생 입건
# https://n.news.naver.com/mnews/article/448/0000367263?sid=102
# 4년 전 시험문제 통째 유출 그 학교서 또…시험 답안 유출 의혹
# https://n.news.naver.com/mnews/article/011/0004080165?sid=102

# %%
# 이미지 추출
import requests as rq
url = 'https://n.news.naver.com/mnews/article/629/0000162958?sid=102'
r = rq.get(url, headers=headers).text
bs = BeautifulSoup(r,'lxml')
target = bs.select_one('#img1')
print(target)
print('-'*100)
print(target['data-src'])
# Out:
# <img class="_LAZY_LOADING" data-src="https://imgnews.pstatic.net/image/629/2022/07/26/202229941658735740_20220726060102195.jpg?type=w647" id="img1"/>
# ----------------------------------------------------------------------------------------------------
# https://imgnews.pstatic.net/image/629/2022/07/26/202229941658735740_20220726060102195.jpg?type=w647

# %% [markdown]
# Q. url = 'https://news.naver.com/main/main.naver?mode=LSD&mid=shm&sid1=100' 사이트에서 뉴스기사를 출력하세요.
# - 용도는 주요 키워드 분석을 위한 데이터 셋 만들기

# %%
from konlpy.tag import Okt
from collections import Counter
from bs4 import BeautifulSoup
import requests

url = 'https://news.naver.com/main/main.nhn?mode=LSD&mid=shm&sid1=100'
rqs = requests.get(url,headers=headers).text
bs = BeautifulSoup(rqs,'lxml')
bs = bs.find_all('div',class_='cluster')
result = []
for i in bs:
    result.append(i.get_text())
bs = re.sub('[^가-힣]+',' ',str(result))

okok = Okt()
okok2 = okok.pos(bs)
okre = []
for i, j in okok2:
    if (j =='Noun')& (len(i)> 1 ):
        okre.append(i)

okreid = dict(Counter(okre).most_common())
okreid = sorted(okreid.items(), key=lambda x:x[1], reverse=True)
okreid
# Out:
# [('경찰', 28),
#  ('뉴스', 21),
#  ('관련', 20),
#  ('보기', 18),
#  ('대통령', 18),
#  ('정부', 15),
#  ('장관', 12),
#  ('민주당', 12),
#  ('신설', 11),
#  ('의원', 10),
#  ('대표', 10),
#  ('오늘', 8),
#  ('일보', 8),
#  ('반발', 8),
#  ('집단', 8),
#  ('폐지', 8),
#  ('윤석열', 8),
#  ('업무', 8),
#  ('문란', 8),
#  ('법무부', 8),
#  ('기사', 7),
#  ('국민', 7),
#  ('권성동', 7),
#  ('보고', 7),
#  ('한동훈', 7),
#  ('한국', 7),
#  ('북송', 6),
#  ('행정안전부', 6),
#  ('기강', 6),
#  ('반대', 6),
#  ('출마', 6),
#  ('박용진', 6),
#  ('울릉도', 6),
#  ('평화', 6),
#  ('강제', 5),
#  ('항의', 5),
#  ('공권력', 5),
#  ('중앙', 5),
#  ('동영상', 5),
#  ('로드맵', 5),
#  ('조속', 5),
#  ('마련', 5),
#  ('대통령실', 5),
#  ('국가', 5),
#  ('농단', 5),
#  ('시행', 5),
#  ('국정', 5),
#  ('재선거', 5),
#  ('이재명', 5),
#  ('한반도', 5),
#  ('워치', 5),
#  ('권영세', 4),
#  ('유엔', 4),
#  ('여가부', 4),
#  ('경제', 4),
#  ('박범계', 4),
#  ('안철수', 4),
#  ('김경수', 4),
#  ('사면', 4),
#  ('공개', 4),
#  ('국회의원', 4),
#  ('박종덕', 4),
#  ('년대', 4),
#  ('셀프', 4),
#  ('공천', 4),
#  ('직접', 4),
#  ('이준석', 4),
#  ('당원', 4),
#  ('원내대표', 4),
#  ('박홍근', 4),
#  ('헤드라인', 3),
#  ('탈북', 3),
#  ('어민', 3),
#  ('승인', 3),
#  ('대해', 3),
#  ('행동', 3),
#  ('용납', 3),
#  ('파이낸셜뉴스', 3),
#  ('가운데', 3),
#  ('국무회의', 3),
#  ('행안부', 3),
#  ('면죄부', 3),
#  ('내년', 3),
#  ('후보', 3),
#  ('연합뉴스', 3),
#  ('이번', 3),
#  ('대한', 3),
#  ('기자회견', 3),
#  ('이상민', 3),
#  ('쿠데타', 3),
#  ('그룹', 3),
#  ('내일', 3),
#  ('선거', 3),
#  ('해명', 3),
#  ('코로나', 3),
#  ('대국민', 3),
#  ('직무', 3),
#  ('대행', 3),
#  ('협력', 3),
#  ('정전협정', 3),
#  ('유엔군', 2),
#  ('우리', 2),
#  ('헤럴드경제', 2),
#  ('정치', 2),
#  ('마찬가지', 2),
#  ('지시', 2),
#  ('여성가족부', 2),
#  ('한겨레', 2),
#  ('김현숙', 2),
#  ('방안', 2),
#  ('국기', 2),
#  ('국민일보', 2),
#  ('속보', 2),
#  ('조선', 2),
#  ('비즈', 2),
#  ('서울', 2),
#  ('현직', 2),
#  ('충돌', 2),
#  ('질문', 2),
#  ('문재인', 2),
#  ('마지막', 2),
#  ('민주', 2),
#  ('통과', 2),
#  ('경남', 2),
#  ('의사', 2),
#  ('페이스북', 2),
#  ('노컷뉴스', 2),
#  ('조기', 2),
#  ('무소속', 2),
#  ('선언', 2),
#  ('국학', 2),
#  ('연합', 2),
#  ('회장', 2),
#  ('추모', 2),
#  ('카투사', 2),
#  ('미국', 2),
#  ('전쟁', 2),
#  ('사자', 2),
#  ('미군', 2),
#  ('유가', 2),
#  ('아버지', 2),
#  ('문화', 2),
#  ('앞서', 2),
#  ('규탄', 2),
#  ('일화', 2),
#  ('논의', 2),
#  ('학번', 2),
#  ('김대중', 2),
#  ('서원', 2),
#  ('연설', 2),
#  ('주자', 2),
#  ('언급', 2),
#  ('계양', 2),
#  ('의혹', 2),
#  ('얼렁뚱땅', 2),
#  ('만남', 2),
#  ('홍보', 2),
#  ('항원', 2),
#  ('검사', 2),
#  ('지원', 2),
#  ('하나회', 2),
#  ('발상', 2),
#  ('사실', 2),
#  ('한용섭', 2),
#  ('주년', 2),
#  ('안내', 1),
#  ('묶음', 1),
#  ('타이틀', 1),
#  ('내용', 1),
#  ('기반', 1),
#  ('자동', 1),
#  ('추출', 1),
#  ('강력', 1),
#  ('통일부', 1),
#  ('당시', 1),
#  ('사령부', 1),
#  ('나중', 1),
#  ('김현정', 1),
#  ('뉴스쇼', 1),
#  ('출연', 1),
#  ('세계', 1),
#  ('안대', 1),
#  ('포승', 1),
#  ('이종섭', 1),
#  ('확인', 1),
#  ('경찰복', 1),
#  ('일부', 1),
#  ('움직임', 1),
#  ('매일경제', 1),
#  ('불가', 1),
#  ('현실', 1),
#  ('그동안', 1),
#  ('팩트', 1),
#  ('생략', 1),
#  ('내부', 1),
#  ('최종', 1),
#  ('지휘', 1),
#  ('감독', 1),
#  ('문제', 1),
#  ('일선', 1),
#  ('라며', 1),
#  ('강도', 1),
#  ('법무', 1),
#  ('질문서', 1),
#  ('고성', 1),
#  ('격돌', 1),
#  ('채널', 1),
#  ('왕중', 1),
#  ('법치', 1),
#  ('민정수', 1),
#  ('인사', 1),
#  ('검증', 1),
#  ('위법', 1),
#  ('통령', 1),
#  ('국회', 1),
#  ('입장', 1),
#  ('의결', 1),
#  ('내달', 1),
#  ('윤수', 1),
#  ('안이', 1),
#  ('공포', 1),
#  ('동시', 1),
#  ('조직', 1),
#  ('파괴', 1),
#  ('사의', 1),
#  ('표명', 1),
#  ('공식', 1),
#  ('지사', 1),
#  ('이상직', 1),
#  ('낙마', 1),
#  ('점화', 1),
#  ('하나', 1),
#  ('무공', 1),
#  ('여부', 1),
#  ('최대', 1),
#  ('관심', 1),
#  ('전북', 1),
#  ('가열', 1),
#  ('분위기', 1),
#  ('학원', 1),
#  ('예정자', 1),
#  ('전북도', 1),
#  ('의회', 1),
#  ('국전', 1),
#  ('유가족', 1),
#  ('먼저', 1),
#  ('준공', 1),
#  ('워싱턴', 1),
#  ('소재', 1),
#  ('배속', 1),
#  ('원단', 1),
#  ('참전용사', 1),
#  ('누구', 1),
#  ('사랑', 1),
#  ('군인', 1),
#  ('카터', 1),
#  ('철수', 1),
#  ('전역', 1),
#  ('싱글', 1),
#  ('러브', 1),
#  ('장군', 1),
#  ('올해', 1),
#  ('애정', 1),
#  ('추진', 1),
#  ('위해', 1),
#  ('용산', 1),
#  ('집무실', 1),
#  ('예정', 1),
#  ('회견', 1),
#  ('정권', 1),
#  ('스스로', 1),
#  ('서한', 1),
#  ('내지', 1),
#  ('도부', 1),
#  ('행정', 1),
#  ('저지', 1),
#  ('여론', 1),
#  ('전도', 1),
#  ('해임', 1),
#  ('건의', 1),
#  ('탄핵', 1),
#  ('단독', 1),
#  ('호프', 1),
#  ('동서', 1),
#  ('재선', 1),
#  ('회동', 1),
#  ('예비', 1),
#  ('경선', 1),
#  ('컷오프', 1),
#  ('처럼', 1),
#  ('동지', 1),
#  ('경쟁', 1),
#  ('인천', 1),
#  ('당권', 1),
#  ('도전', 1),
#  ('나선', 1),
#  ('논란', 1),
#  ('아시아', 1),
#  ('장외', 1),
#  ('전날', 1),
#  ('포항', 1),
#  ('대구', 1),
#  ('경북', 1),
#  ('행보', 1),
#  ('시동', 1),
#  ('윤리', 1),
#  ('위원회', 1),
#  ('징계', 1),
#  ('이후', 1),
#  ('전국', 1),
#  ('명의', 1),
#  ('해도', 1),
#  ('사진', 1),
#  ('코끼리', 1),
#  ('바위', 1),
#  ('정례', 1),
#  ('브리핑', 1),
#  ('횟수', 1),
#  ('방역', 1),
#  ('지침', 1),
#  ('확산', 1),
#  ('전문', 1),
#  ('가용', 1),
#  ('비용', 1),
#  ('진정', 1),
#  ('측근', 1),
#  ('이데일리', 1),
#  ('안정', 1),
#  ('운영', 1),
#  ('상황', 1),
#  ('사과', 1),
#  ('강원', 1),
#  ('각각', 1),
#  ('범죄예방', 1),
#  ('외국인', 1),
#  ('정책', 1),
#  ('중점', 1),
#  ('독대', 1),
#  ('광복절', 1),
#  ('특사', 1),
#  ('총장', 1),
#  ('인선', 1),
#  ('주목', 1),
#  ('진행', 1),
#  ('다른', 1),
#  ('부처', 1),
#  ('배석', 1),
#  ('소수', 1),
#  ('참모', 1),
#  ('연재', 1),
#  ('중이', 1),
#  ('까닭', 1),
#  ('역사', 1),
#  ('왜곡', 1),
#  ('국익', 1),
#  ('가치', 1),
#  ('국방대', 1),
#  ('부총', 1),
#  ('체결', 1),
#  ('기념일', 1),
#  ('잊힌', 1),
#  ('중요', 1),
#  ('조항', 1),
#  ('박영호', 1),
#  ('통한', 1),
#  ('토대', 1),
#  ('혜성', 1),
#  ('대화', 1),
#  ('거래', 1),
#  ('이혁', 1),
#  ('촉진자', 1),
#  ('박현', 1),
#  ('도의', 1),
#  ('사우디', 1),
#  ('급등', 1),
#  ('증산', 1),
#  ('애걸', 1)]

# %% [markdown]
# #### 과제0726_2
#
# 네이버 카테고리별 기사를 아래 카테고리 정의를 기준으로 크롤링한 후 불필요한 공백을 제거하고 한글만으로 된 데이터 프레임을 출력하세요.
# (용도는 전체, 카테고리별 키워드 분석을 위한 시각화임을 감안하여 데이터 수집 및 전처리 수행)
#
# - 카테고리 정의
#     - 100 정치
#         - (청와대[264] + 국회/정당[265] + 북한[268] + 국방/외교[267])
#
#     - 101 경제
#         - (금융[259] + 증권[258] + 산업/재계[261] + 글로벌 경제[262] + 부동산[260])
#
#     - 103 생활/문화
#         - (건강정보[241] + 여행/레저[237] + 공연/전시[242] + 날씨[248] + 생활문화 일반[245])
#
#     - 105 IT/과학
#         - (통신/뉴미디어[227] + IT 일반[230] + 컴퓨터[283] + 과학 일반[228])
#
# - 카테고리별 1000개, 총 4천개로 구성된 데이터프레임 생성

# %%
# 웹구조 파악 : sid1 = 100, sid2 = 264, page = 
https://news.naver.com/main/main.naver?mode=LSD&mid=shm&sid1=100
https://news.naver.com/main/list.naver?mode=LS2D&mid=shm&sid1=100&sid2=265
https://news.naver.com/main/list.naver?mode=LS2D&sid2=265&sid1=100&mid=shm&date=20220726&page=27
    
url = 'https://news.naver.com/main/list.naver?mode=LS2D&sid2='+str(cat)+'&sid1=100&mid=shm&date=20220726&page='+str(i+1)

# %%
import pandas as pd
news_df = pd.DataFrame(columns=['news','category'])
news_df
# Out:
# Empty DataFrame
# Columns: [news, category]
# Index: []

# %%
from bs4 import BeautifulSoup
import requests

cats=[264,265,268,267]
ind=0 # 행 번호
for cat in cats:
    for i in range(15):
        url = 'https://news.naver.com/main/list.naver?mode=LS2D&sid2='+str(cat)+'&sid1=100&mid=shm&date=20220726&page='+str(i+1)
        headers = {"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.45 Safari/537.36"}
        news = requests.get(url, headers=headers)
        bs = BeautifulSoup(news.text, 'html.parser')
        links = bs.select('#main_content > div > ul > li > dl > dt > a')
        newslinks=[]
        for j, a in enumerate(links):
            newslink = a.get('href')
            newslinks.append(newslink)
            newslinks = list(set(newslinks)) # 중복 기사 제거
            
        for link in newslinks:
            res2 = requests.get(link, headers=headers).text
            bs2 = BeautifulSoup(res2, 'html.parser')
            news = bs2.find('div',id='dic_area').text
            news = re.sub('\n','',news) # 개행 공백으로
            news = re.sub('\t','',news) # tab 공백으로
            news_df.loc[ind] = [news,cat]
            ind += 1
news_df
# Out:
#                                                    news  category
# 0     [[the300](상보)]윤석열 대통령이 26일 용산 대통령실 집무실에서 한동훈 법...       264
# 1     윤석열 대통령이 26일 복심인 한동훈 법무부 장관에 "기업활동을 위축시키는 과도한 ...       264
# 2     한동훈 법무장관, 첫 대통령 업무보고윤석열 대통령이 26일 한동훈 법무부 장관으로부...       264
# 3     "검사 일은 사건·범죄 다른 고려 없이 수사하는 것…제대로 지원할 분이 총장 돼야"...       264
# 4     "업무보고서 사면 얘기 안 나와…검찰총장, 상식·정의 따라 검찰 이끄는 분 될 것"...       264
# ...                                                 ...       ...
# 1159      (영종도=연합뉴스) 임헌정 기자 = 이종섭 국방부 장관이 미국 워싱턴 D.C...       267
# 1160      (서울=연합뉴스) 김승두 기자 = 한덕수 국무총리(왼쪽)와 추경호 경제부총리...       267
# 1161      (서울=연합뉴스) 김승두 기자 = 한덕수 국무총리(오른쪽)가 26일 오전 정...       267
# 1162      (서울=연합뉴스) 김승두 기자 = 한덕수 국무총리(왼쪽)와 추경호 경제부총리...       267
# 1163      (영종도=연합뉴스) 임헌정 기자 = 이종섭 국방부 장관이 미국 워싱턴 D.C...       267
#
# [1164 rows x 2 columns]
